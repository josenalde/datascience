# %% [markdown]
# <a href="https://colab.research.google.com/github/josenalde/datascience/blob/main/webdriver_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Instalar o chromedriver

# %%
# !apt install chromium-chromedriver

# %% [markdown]
# 2) Inserir o chromedriver, arquivo com permissão de execução no PATH

# %%
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
# Out:
# cp: cannot stat '/usr/lib/chromium-browser/chromedriver': No such file or directory

# %%
# !sudo apt-get install -y xvfb

# %%
# !sudo apt-get -y install xorg xvfb gtk2-engines-pixbuf
# !sudo apt-get -y install dbus-x11 xfonts-base xfonts-100dpi xfonts-75dpi xfonts-cyrillic xfonts-scalable

# %%
#!pip install -U selenium #- primeira vez instalar

from selenium import webdriver

# --- caso não funcione com o procedimento mais simples --- 
#!pip install webdriver-manager
#from webdriver_manager.chrome import ChromeDriverManager


options = webdriver.ChromeOptions()
options.add_argument('--headless') # O mais importante, não renderiza parte gráfica
options.add_argument('window-size=1920x1080')
options.add_argument('--no-sandbox') #obrigatório, caso contrário gera erro, pois está abrindo como root e exige --no-sandbox

#msg de erro: (The process started from chrome location /usr/bin/chromium-browser is no longer running, so ChromeDriver is assuming that Chrome has crashed.)

options.add_argument('--disable-dev-shm-usage')
options.add_argument('--disable-gpu')
options.add_argument('--disable-extensions')
# outras opções:
""" disable-gpu
    ignore-certificate-errors
    disable-extensions
    etc.
"""
# altere aqui para o seu PATH incluindo o .exe
#driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
driver = webdriver.Chrome(executable_path = r'/usr/lib/chromium-browser/chromedriver', options = options)

""" o método get() abre a URL e aguarda até todo o conteúdo estar carregado. O WebDriver 
    aguardará toda a página estar carregada até retornar o controle para o script """

url1 = 'https://www.loteriaseresultados.com.br/index.php/megasena/concurso/2342'
#url2 = 'https://febrace.org.br/'
url3 = 'https://www.loteriaseresultados.com.br/'
url4 = 'http://loterias.caixa.gov.br/wps/portal/loterias/'
driver.get(url4)
# verifica se abriu ok
print(driver.current_url)

""" comandos selenium de busca (retornam WebElements ou Exceção noSuchElementException):
    URL: https://selenium-python.readthedocs.io/locating-elements.html#locating-elements
    find_element_by_class_name(className)
    find_element_by_id
    find_element_by_css_selector
    find_element_by_link_text (por texto de href)
    find_element_by_partial_link_text (por pedaço de texto de href)
    find_element_by_tag_name
    find_element_by_xpath
    
    Este comando retorna a primeira ocorrência. Para encontrar todas, as funções acima possuem a versão que retorna lista
    trocando _element por _elements (find_elements_by_id) etc.
    
"""
    
#try:
    
    # uma opção é obter todo o body (ou parte mais específica) da página com o selenium/webdriver e passar ao BSoup para análise padrão
#body = driver.find_element_by_tag_name('body')
#html = body.get_attribute('innerHTML')
#soupPage = soup(html, 'html5lib')
#spanList = soupPage.findAll( "span", class_='white--text font-weight-bold')
#print(len(spanList))
#for n in range(6):
#    print(spanList[n].text)
    
    
print('-------- segundo método ---------')
    
# No caso de classe ou id com espaço, a sintaxe abaixo é a indicada, colocar simplesmente o nome da classe não reconhece
    
content = driver.find_elements_by_css_selector("span[class='white--text font-weight-bold']")
body = driver.find_element_by_tag_name('body')

html = body.get_attribute('innerHTML')
print(html)
# Será retornada uma lista com os elementos, portanto, podemos percorrer. Ao olhar a URl, vemos 09 elementos com esta
# classe, e só estamos interessados nos 06 primeiros. Então, faremos um laço:
    
#for n in range(6):
#    print(content[n].get_attribute('innerHTML'))

#except:
#    print('criterio nao encontrado')
    
print('Terminei a raspagem de dados')
driver.close()
# Out:
# http://loterias.caixa.gov.br/wps/portal/loterias/
# -------- segundo método ---------
#
# 	<div class="wpthemeFrame">
# 		<!-- BEGIN cabecalho wps -->
#
#
#
#
#
# 	<header class="main-header" id="header-home">
#     <div id="main-logo">
#      <a class="ir" href="http://www.caixa.gov.br/Paginas/home-caixa.aspx" tabindex="2">Caixa</a>
#     </div>
#     <div class="header-content">
#         <nav class="hotlinks clearfix">
#             <ul class="helper">
#                 <li><a class="highlight" href="http://www.caixa.gov.br/atendimento/internet-banking">Ajuda para acessar ›</a></li>
#             </ul>
#             <ul class="languages">
#                             <li><a title="http://www14.caixa.gov.br/portal/idiomas/english/financial_information/bondholders_information" href="http://www14.caixa.gov.br/portal/idiomas/english/financial_information/bondholders_information">EN</a> /</li>
#                             <li><a title="http://www.espacioinmigrantescaixa.com.br/" href="http://www.espacioinmigrantescaixa.com.br/">ES</a> /</li>
#                             <li class="rybena">
# 			<a title="Tradutor de libras" class="ico_libras_2011" tabindex="12">Tradutor de libras</a>
# 		</li>
#                         </ul>
#
#             <ul>
#                             <li><a title="Caixa A-Z" href="http://www.caixa.gov.br/caixa-a-z">Caixa A-Z</a></li>
#                             <li><a title="Downloads" href="http://www.caixa.gov.br/site/paginas/downloads.aspx">Downloads</a></li>
#                             <li><a title="Sobre a Caixa" href="http://www.caixa.gov.br/sobre-a-caixa">Sobre a Caixa</a></li>
#                         </ul>
#         </nav>
#
#         <nav class="clearfix" id="main-nav">
#             <div class="main-menu">
#                 <ul>
#                     <li class="has-submenu">
#                         <a href="#">Produtos</a>
#                         <div class="submenu submenu-produtos submenu-two-columns clearfix">
#                             <div class="submenu-column">
#                                 <p class="submenu-title">Para você</p>
#
#                                 <ul>
# <li><a title="http://www.caixa.gov.br/voce/contas" href="http://www.caixa.gov.br/voce/contas">Contas</a></li>
# <li><a title="http://www.caixa.gov.br/voce/habitacao" href="http://www.caixa.gov.br/voce/habitacao">Habitação</a></li>
# <li><a title="http://www.caixa.gov.br/voce/poupanca-e-investimentos" href="http://www.caixa.gov.br/voce/poupanca-e-investimentos">Poupança e Investimentos</a></li>
# <li><a title="http://www.caixa.gov.br/voce/cartoes" href="http://www.caixa.gov.br/voce/cartoes">Cartões</a></li>
# <li><a title="http://www.caixa.gov.br/voce/credito-financiamento" href="http://www.caixa.gov.br/voce/credito-financiamento">Crédito e Financiamento</a></li>
# <li><a title="http://www.caixa.gov.br/voce/Seguros" href="http://www.caixa.gov.br/voce/Seguros">Seguros</a></li>
# <li><a title="http://www.caixa.gov.br/voce/previdencia" href="http://www.caixa.gov.br/voce/previdencia">Previdência Privada</a></li>
# <li><a title="http://loterias.caixa.gov.br/" href="http://loterias.caixa.gov.br/">Loterias</a></li>
# <li class="see-more"><a title="Todos os produtos para você" href="http://www.caixa.gov.br/voce">Todos os produtos para você ›</a></li>
# </ul>
#                             </div>
#
#                             <div class="submenu-column">
#                                 <p class="submenu-title">Empresas</p>
#                                 <ul>
# <li><a title="http://www.caixa.gov.br/empresa/contas" href="http://www.caixa.gov.br/empresa/contas">Contas</a></li>
# <li><a title="http://www.caixa.gov.br/voce/poupanca-e-investimentos" href="http://www.caixa.gov.br/voce/poupanca-e-investimentos">Investimentos</a></li>
# <li><a title="http://www.caixa.gov.br/empresa/cartoes" href="http://www.caixa.gov.br/empresa/cartoes">Cartões</a></li>
# <li><a title="http://www.caixa.gov.br/empresa/credito-financiamento" href="http://www.caixa.gov.br/empresa/credito-financiamento">Crédito e Financiamento</a></li>
# <li><a title="http://www.caixa.gov.br/empresa/credito-financiamento/imoveis" href="http://www.caixa.gov.br/empresa/credito-financiamento/imoveis">Imóveis</a></li>
# <li><a title="http://www.caixa.gov.br/poder-publico/apoio-poder-publico/servicos-caixa/servicos-judiciarios" href="http://www.caixa.gov.br/poder-publico/apoio-poder-publico/servicos-caixa/servicos-judiciarios">Depósito judicial</a></li>
# <li><a title="http://www.caixa.gov.br/empresa/credito-financiamento/credito-rural" href="http://www.caixa.gov.br/empresa/credito-financiamento/credito-rural">Crédito Rural</a></li>
# <li><a title="http://www.caixa.gov.br/empresa/conectividade-social" href="http://www.caixa.gov.br/empresa/conectividade-social">Conectividade Social</a></li>
# <li><a title="http://www.caixa.gov.br/empresa/fgts-empresas/" href="http://www.caixa.gov.br/empresa/fgts-empresas/">FGTS</a></li>
# <li class="see-more"><a title="Todos os produtos para empresas" href="http://www.caixa.gov.br/empresa">Todos os produtos para empresas ›</a></li>
# </ul>
# 							</div>
#                         </div>
#                     </li>
#                     <li class="has-submenu">
#                         <a href="#">Benefícios e Programas</a>
#                         <div class="submenu submenu-beneficios clearfix">
#                             <div class="submenu-column">
#                                 <p class="submenu-title">Benefícios do trabalhador</p>
#                                 <ul>
# <li><a title="http://www.caixa.gov.br/beneficios-trabalhador/fgts" href="http://www.caixa.gov.br/beneficios-trabalhador/fgts">FGTS</a></li>
# <li><a title="http://www.caixa.gov.br/beneficios-trabalhador/pis" href="http://www.caixa.gov.br/beneficios-trabalhador/pis">PIS</a></li>
# <li><a title="http://www.caixa.gov.br/beneficios-trabalhador/inss" href="http://www.caixa.gov.br/beneficios-trabalhador/inss">INSS</a></li>
# <li><a title="http://www.caixa.gov.br/beneficios-trabalhador/seguro-desemprego" href="http://www.caixa.gov.br/beneficios-trabalhador/seguro-desemprego">Seguro-Desemprego</a></li>
# <li class="see-more"><a title="Todos os benefícios" href="http://www.caixa.gov.br/beneficios-trabalhador">Todos os benefícios ›</a></li>
# </ul>
#                             </div>
#
#                             <div class="submenu-column">
#                                 <p class="submenu-title">Programas sociais</p>
#
#                                 <ul>
# <li><a title="http://www.caixa.gov.br/voce/habitacao/minha-casa-minha-vida" href="http://www.caixa.gov.br/voce/habitacao/minha-casa-minha-vida">Minha Casa Minha Vida</a></li>
# <li><a title="http://www.caixa.gov.br/programas-sociais/minha-casa-melhor" href="http://www.caixa.gov.br/programas-sociais/minha-casa-melhor">Minha Casa Melhor</a></li>
# <li><a title="http://www.caixa.gov.br/programas-sociais/bolsa-familia" href="http://www.caixa.gov.br/programas-sociais/bolsa-familia">Bolsa Família</a></li>
# <li><a title="http://www.caixa.gov.br/programas-sociais/fies" href="http://www.caixa.gov.br/programas-sociais/fies">FIES</a></li>
# <li class="see-more"><a title="Todos os programas" href="http://www.caixa.gov.br/programas-sociais">Todos os programas ›</a></li>
# </ul>
#                             </div>
#
#                             <div class="submenu-column">
#                                 <p class="submenu-title">Cadastros do governo</p>
#                                <ul>
# <li><a title="http://www.caixa.gov.br/cadastros/cartao-cidadao" href="http://www.caixa.gov.br/cadastros/cartao-cidadao">Cartão do Cidadão</a></li>
# <li><a title="http://www.caixa.gov.br/cadastros/cpf" href="http://www.caixa.gov.br/cadastros/cpf">CPF</a></li>
# <li><a title="http://www.caixa.gov.br/cadastros/cadastro-unico" href="http://www.caixa.gov.br/cadastros/cadastro-unico">Cadastro Único</a></li>
# <li><a title="http://www.caixa.gov.br/cadastros/nis/" href="http://www.caixa.gov.br/cadastros/nis/">NIS</a></li>
# <li class="see-more"><a title="Todos os cadastros" href="http://www.caixa.gov.br/cadastros">Todos os cadastros ›</a></li>
# </ul>
#                             </div>
#                         </div>
#                     </li>
#
#                     <li class="has-submenu">
#                         <a href="#">Atendimento</a>
# 						<div class="submenu submenu-atendimento clearfix"><!-- Sub Menu -->
# 							<div class="submenu-column">
# 								<p class="submenu-title">Canais </p>
#                                 <ul>
# <li><a title="http://www.caixa.gov.br/atendimento/Paginas/default.aspx" href="http://www.caixa.gov.br/atendimento/Paginas/default.aspx">Atendimento para você e para empresa</a></li>
# <li><a title="http://fale-conosco.caixa.gov.br/" href="http://fale-conosco.caixa.gov.br/">Fale conosco</a></li>
# <li><a title="http://www.caixa.gov.br/atendimento/Paginas/default.aspx#encontre" href="http://www.caixa.gov.br/atendimento/Paginas/default.aspx#encontre">Endereços</a></li>
# </ul>
# 							</div>
#                             <div class="submenu-column">
#                                 <p class="submenu-title">Ferramentas </p>
#                                     <ul>
# <li><a title="http://www.caixa.gov.br/atendimento/aplicativos" href="http://www.caixa.gov.br/atendimento/aplicativos">Aplicativos</a></li>
# <li><a title="http://www.caixa.gov.br/site/paginas/downloads.aspx" href="http://www.caixa.gov.br/site/paginas/downloads.aspx">Downloads</a></li>
# <li><a title="http://www.caixa.gov.br/atendimento/2-via-boleto" href="http://www.caixa.gov.br/atendimento/2-via-boleto">2ª via de boletos</a></li>
# </ul>
#                             </div>
# 							<div class="submenu-column">
# 								<p class="submenu-title">Institucional </p>
#                                <ul>
# <li><a title="http://www.caixa.gov.br/sustentabilidade/responsabilidade-social/agencia-barco/" href="http://www.caixa.gov.br/sustentabilidade/responsabilidade-social/agencia-barco/">Agência-Barco</a></li>
# <li><a title="http://www.caixa.gov.br/sustentabilidade" href="http://www.caixa.gov.br/sustentabilidade">Sustentabilidade</a></li>
# <li><a title="http://www.caixa.gov.br/sobre-a-caixa/trabalhe-na-caixa" href="http://www.caixa.gov.br/sobre-a-caixa/trabalhe-na-caixa">Trabalhe na Caixa</a></li>
# <li class="see-more"><a title="Tudo sobre a Caixa" href="http://www.caixa.gov.br/sobre-a-caixa">Tudo sobre a Caixa ›</a></li>
# </ul>
#                             </div>
#                         </div>
#                     </li>
#                     <li>
#                         <a class="soft" href="http://www.caixa.gov.br/poder-publico/Paginas/default.aspx">Poder Público</a>
#
#                         <nav class="menu-hotlinks clearfix hidden-desktop">
#                             <ul>
#                             <li><a title="Caixa A-Z" href="http://www.caixa.gov.br/caixa-a-z/Paginas/default.aspx">Caixa A-Z</a></li>
#                             <li><a title="Downloads" href="http://www.caixa.gov.br/site/paginas/downloads.aspx">Downloads</a></li>
#                             <li><a title="Sobre a Caixa" href="http://www.caixa.gov.br/caixa-a-z/Paginas/default.aspx">Sobre a Caixa</a></li>
#                         </ul>
#                             <ul class="languages">
#                             <li><a title="http://www14.caixa.gov.br/portal/idiomas/english/financial_information/bondholders_information" href="http://www14.caixa.gov.br/portal/idiomas/english/financial_information/bondholders_information">EN</a> /</li>
#                             <li><a title="http://www.espacioinmigrantescaixa.com.br/" href="http://www.espacioinmigrantescaixa.com.br/">ES</a> /</li>
#                         </ul>
#                         </nav>
#                     </li>
#                 </ul>
#
#                 <div class="search-box">
#                     <form method="get" action="http://www.caixa.gov.br/site/Paginas/Pesquisa.aspx" id="CONNECTFORMGET">
#                         <input placeholder="Busque na Caixa" class="search-input" autocomplete="off" type="text" id="q" name="k">
#                         <button class="ir" type="submit">Buscar</button>
#                     <input type="HIDDEN" name="http://www.caixa.gov.br/site/Paginas/Pesquisa.aspx"><input value="TRUE" type="HIDDEN" name="CONNECTFORMGET"></form>
#
#                 </div>
#             </div>
#
#             <div class="account">
#                 <button class="submit-d submit-orange submit-big submit-non-fluid fa fa-lock" title="Acessar minha conta" onclick="window.location.href='https://internetbanking.caixa.gov.br/SIIBC/index.processa'" tabindex="1">Acessar minha conta </button>
#             </div>
#
#             <div class="mobile-account visible-mobile">
#                 <a href="https://internetbanking.caixa.gov.br/SIIBC/index.processa">Conta</a>
#             </div>
#
#             <div class="mobile-menu hidden-desktop">
#                 <a href="#">Menu</a>
#             </div>
#
#
#         </nav>
#     </div>
# </header>
#
#
# <div class="wpthemeMainContent" role="main">
#
# 					<div class="wpthemeInner">
# 						<!-- asa markup contributions for pages -->
#
#
# <div class="asa.page" id="asa.page" style="display:none;">
# 	<span class="asa.page.id">Z6_61L0H0G0JGPC50AODB90303005</span>
#
#
#
# </div>
#
# <!-- a rel="dynamic-content" href="dyn-cs:id:customTheme_crumbTrail"></a -->
# 						<div class="wpthemeClear"></div>
#
# <div class="wpthemeInner">
# 	<div id="wpthemeStatusBarContainer" class="lotusui30">
#
# 		<noscript>
# 			<div class="lotusMessage2" role="alert" wairole="alert">
# 				<img class="lotusIcon lotusIconMsgError" src="icons/blank.gif" alt="Error" />
# 				<span class="lotusAltText">Error:</span>
# 				<div class="lotusMessageBody">Javascript está desativado neste navegador. Esta página requer Javascript. Modifique as configurações do seu navegador para permitir que o Javascript seja executado. Consulte a documentação do navegador para as instruções específicas.</div>
# 			</div>
# 		</noscript>
# 	</div>
# </div></div>
#
# 					<!-- required - do not remove -->
# 					<div style="display:none" id="portletState">{}</div><div id="layoutContainers" class="wpthemeLayoutContainers wpthemeLayoutContainersHidden">
# 						<div class="wpthemeInner">
# 							<div class="hiddenWidgetsDiv">
# 	<!-- widgets in this container are hidden in the UI by default -->
# 	<div class="component-container ibmDndRow wpthemeCol12of12 hiddenWidgetsContainer wpthemeFull id-Z7_61L0H0G0JGPC50AODB903030G0" name="ibmHiddenWidgets"></div><div style="clear:both"></div>
# </div>
# <div class="wptheme1Col">
# 	<div class="component-container wpthemeCol wpthemePrimary wpthemeLeft wpthemeCol12of12 ibmDndColumn wpthemeFull id-Z7_61L0H0G0J0E1D0AKA2JDBJ00O6" name="ibmMainContainerTop"><div class="component-control id-Z7_HGK818G0K8DL20ARD3LPDT1GV5"><span id="Z7_HGK818G0K8DL20ARD3LPDT1GV5"></span><section class="ibmPortalControl wpthemeControl wpthemeHidden a11yRegionTarget" role="region" aria-labelledby="wpRegionIdZ7_HGK818G0K8DL20ARD3LPDT1GV5">
#
#
#
#
# 	<div class="asa.portlet" id="asa.portlet.Z7_HGK818G0K8DL20ARD3LPDT1GV5" style="display:none;">
# 		<span class="asa.portlet.id">Z7_HGK818G0K8DL20ARD3LPDT1GV5</span>
#
#
#
# 	</div>
#
# <!-- start header markup -->
# 	<header class="wpthemeControlHeader dojoDndHandle">
# 		<div class="wpthemeInner">
# 			<h2>
# 				<!-- lm-dynamic-title node marks location for dynamic title support -->
#  				<span class="lm-dynamic-title asa.portlet.title a11yRegionLabel" id="wpRegionIdZ7_HGK818G0K8DL20ARD3LPDT1GV5"><span lang="pt-BR" dir="ltr">SIWIC Destaque Home</span></span>
# 			</h2>
# 			<a aria-haspopup="true" aria-label="Menu Exibir" href="javascript:;" class="wpthemeIcon wpthemeMenuFocus" tabindex="0" onclick="wptheme.contextMenu.init(this, 'skinAction', {'navID':ibmCfg.portalConfig.currentPageOID,'windowID':wptheme.getWindowIDFromSkin(this)});">
# 				<span title="Menu Exibir"><img aria-label="Menu Exibir" alt="" src="/wps/themeModules/themes/html/dynamicSpots/icons/blank.gif"></span>
# 				<span class="wpthemeAltText">Ações</span>
# 				<span class="wpthemeMenuRight">
# 					<div class="wpthemeMenuBorder">
# 						<div class="wpthemeMenuNotchBorder"></div>
# 						<!-- define the menu item template inside the "ul" element.  only "css-class", "description", and "title" are handled by the theme's sample javascript. -->
# 						<ul class="wpthemeMenuDropDown wpthemeTemplateMenu" role="menu">
# 							<li class="${css-class}" role="menuitem" tabindex="-1"><span class="wpthemeMenuText">${title}</span></li>
# 						</ul>
# 					</div>
# 					<!-- Template for loading -->
# 					<div class="wpthemeMenuLoading wpthemeTemplateLoading">Carregando...</div>
# 					<!-- Template for submenu -->
# 					<div class="wpthemeAnchorSubmenu wpthemeTemplateSubmenu">
# 						<div class="wpthemeMenuBorder wpthemeMenuSubmenu">
# 							<ul id="${submenu-id}" class="wpthemeMenuDropDown" role="menu"><li role="menuitem" tabindex="-1"></li></ul>
# 						</div>
# 					</div>
# 				</span>
# 			</a>
# 		</div>
# 	</header>
#
# 	<div class="wpthemeControlBody wpthemeOverflowAuto wpthemeClear"> <!-- lm:control dynamic spot injects markup of layout control -->
# 	<!-- asa.overlay marks the node that the AsaOverlayWidget will be placed in -->
# 		<div style="position:relative; z-index: 1;">
# 			<div class="analytics.overlay"></div>
# 		</div>
#
#
#
#
#
# <style type="text/css">
# <!--
# .nome-loteria {
# 	background: rgba(0, 0, 0, 0)
# 		url("http://caixa.gov.br/Style Library/images/icon-loteria.png")
# 		no-repeat scroll left center;
# 	float: left;
# 	padding-left: 52px;
# 	position: relative;
# 	width: 40%
# }
#
# .nome-loteria p {
# 	font-family: "FuturaWebBold", sans-serif;
# 	margin: 0;
# 	text-transform: uppercase
# }
#
# .sorteio-resultado {
# 	margin: 0 auto;
# 	width: auto
# }
#
# .sorteio-resultado .resultado-loteria {
# 	margin: 30px 0;
# 	text-align: center
# }
#
# #megaVirada .megasenadavirada>p {
# 	font-style: italic;
# 	font-weight: bolder;
# 	letter-spacing: -1px
# }
#
# #megaVirada .megasenadavirada>.description {
# 	font-weight: 200;
# 	line-height: unset;
# 	margin-top: 0;
# 	padding-top: 0
# }
#
# #megaVirada .only-resultado .inline .description {
# 	color: #fff;
# 	font-family: "FuturaWeb", sans-serif;
# 	font-size: 1.3rem;
# 	font-weight: 400
# }
#
# #megaVirada .only-resultado .inline .description span {
# 	font-weight: 700
# }
#
# #megaVirada .only-resultado .inline .action a {
# 	border: 1px solid #000;
# 	font-size: 1.3rem;
# 	height: auto;
# 	padding: .6rem 1.5rem
# }
#
# #megaVirada .only-resultado .inline .action a span {
# 	font-size: .8rem
# }
#
# #megaVirada .resultado-loteria {
# 	margin-left: 0
# }
#
# @media screen and (max-width: 37.49em) {
# 	.slide-modelo-04 .only-resultado .sorteio-loteria {
# 		left: 0;
# 		position: relative !important;
# 		top: 0;
# 		width: 90%;
# 		margin: 0 auto
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria {
# 		background: rgba(0, 0, 0, 0) none repeat scroll 0 0 !important;
# 		padding-left: 0;
# 		margin-top: 50px;
# 		text-align: center
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria p.description {
# 		color: #fff;
# 		font-weight: 400;
# 		font-size: 1.4rem
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria p.description span {
# 		font-weight: 700
# 	}
# 	.sorteio-resultado .resultado-loteria>li {
# 		min-width: 42px
# 	}
# 	.slide-modelo-04 .only-resultado .article-actions>.description {
# 		font-size: 1.5rem;
# 		line-height: 2.6rem
# 	}
# 	#content .slide-modelo-04 .only-resultado .article-actions {
# 		min-height: 300px !important
# 	}
# 	.slide-modelo-04 .only-resultado .article-actions>.action {
# 		margin-top: 30px !important
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria {
# 		margin-top: 1rem
# 	}
# 	#megaVirada .megasenadavirada>p {
# 		color: #fff;
# 		font-size: 1.6rem;
# 		color: #fff;
# 		font-size: 1.6rem
# 	}
# 	#megaVirada .resultado-loteria {
# 		margin-left: 0
# 	}
# 	.nome-loteria {
# 		width: 100%
# 	}
# 	.resultado-loteria>li {
# 		font-size: 1.1rem;
# 		margin: 0
# 	}
# 	#megaVirada .only-resultado .inline .description {
# 		text-align: center
# 	}
# }
#
# @media screen and (min-width: 37.5em) {
# 	.sorteio-resultado .resultado-loteria {
# 		float: none
# 	}
# 	.sorteio-resultado .resultado-loteria>li {
# 		border-radius: 65px;
# 		font-size: 3.1rem;
# 		min-width: 82px;
# 		text-align: center;
# 		font-weight: 400
# 	}
# 	.only-resultado .nome-loteria {
# 		width: 90%;
# 		background-position: left top !important
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria p {
# 		color: #fff;
# 		font-weight: 700;
# 		font-size: 1rem;
# 		float: none;
# 		width: 100%
# 	}
# 	.only-resultado .nome-loteria p.description {
# 		color: #fff;
# 		font-weight: 400;
# 		font-size: 1rem;
# 		width: 100%
# 	}
# 	.only-resultado .nome-loteria p.description span {
# 		font-weight: 700
# 	}
# 	.only-resultado .megasenadavirada {
# 		background-position: left center !important
# 	}
# 	.only-resultado .megasenadavirada p.description {
# 		width: 100% !important;
# 		font-size: 1.3rem !important;
# 		margin-top: -5px !important
# 	}
# 	.sorteio-resultado .resultado-loteria>li {
# 		font-size: 2.2rem;
# 		min-width: 66px
# 	}
# 	#megaVirada .only-resultado .inline .description {
# 		width: 58%;
# 		float: left;
# 		padding-right: 1rem;
# 		margin: 0;
# 		padding-top: 0
# 	}
# 	#megaVirada .only-resultado .inline .action {
# 		width: 42%;
# 		float: left;
# 		margin: 0;
# 		padding-top: 0
# 	}
# 	#megaVirada {
# 		padding: 0 2rem
# 	}
# }
#
# @media screen and (min-width: 50em) and (max-width: 62.5em) {
# 	.slide-modelo-04 .article-actions>.description {
# 		float: left;
# 		margin: 0 5% 10px auto;
# 		width: 55%
# 	}
# 	.slide-modelo-04 .article-actions>.action {
# 		padding-top: 25px
# 	}
# 	#megaVirada {
# 		margin: auto;
# 		max-width: 640px
# 	}
# 	.sorteio-resultado .resultado-loteria>li {
# 		font-size: 3.1rem;
# 		min-width: 83px
# 	}
# }
#
# @media screen and (min-width: 62.5em) {
# 	.sorteio-resultado .resultado-loteria {
# 		text-align: left
# 	}
# 	.sorteio-resultado .resultado-loteria>li {
# 		border-radius: 65px;
# 		font-size: 3.5rem;
# 		min-width: 93px
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria {
# 		width: 90%;
# 		background-position: left 5px !important
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria p {
# 		color: #fff;
# 		font-weight: 700;
# 		float: left;
# 		width: 245px;
# 		font-size: 1.5rem !important
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria p.description {
# 		color: #fff;
# 		font-weight: 400;
# 		font-size: .9rem;
# 		width: 180px;
# 		padding-top: 5px
# 	}
# 	.slide-modelo-04 .only-resultado .nome-loteria p.description span {
# 		font-weight: 700
# 	}
# 	#megaVirada {
# 		margin: auto;
# 		max-width: 690px;
# 		padding: 0
# 	}
# 	#megaVirada .only-resultado .inline .description, #megaVirada .only-resultado .inline .action
# 		{
# 		float: left;
# 		width: 50%
# 	}
# 	#megaVirada .only-resultado .inline .action {
# 		padding-left: 2rem;
# 		margin-top: 0
# 	}
# 	.kilo {
# 	  font-size: 5.40rem !important;
# 	}
# }
#
# @media screen and (min-width: 75em) {
# 	.sorteio-resultado .resultado-loteria {
# 		margin: 40px 0 40px 4%;
# 		text-align: left
# 	}
# 	.sorteio-resultado .resultado-loteria>li {
# 		border-radius: 65px;
# 		font-size: 4rem;
# 		min-width: 102px
# 	}
# }
# -->
# </style>
# <link rel="stylesheet" type="text/css" href="/wps/PA_loterias-pub/css/quinaSaoJoao.css">
#
#
# <script language="JavaScript" src="/wps/PA_loterias-pub/js/loteriasUtil.js"></script>
#
# <div class="content-hero hero-loteria blue-hero">
#
#
#
#
# 	<p class="breadcrumb">
# 		<a href="http://www.caixa.gov.br" title="Início">Início</a> › <a href="http://www.caixa.gov.br/voce/Paginas/default.aspx" title="Produtos para você">Produtos para você</a> ›
# 	</p>
#
# 	<h2>Loterias</h2>
# 	<p class="hero-description">Loterias Caixa: Já pensou?</p>
#
#
#
#
#
#
# 					<!-- mega sena -->
#
#
#
# 						<div class="content-wrapper clearfix">
#
# 					<div title="Mega-Sena" class="logo-mega-sena">
# 						<p class="description">Sorteio nº 2349 .
# 							03/03/2021</p>
# 					</div>
#
#
#
#
# 						<h2 class="kilo">
# 							<span class="beta">R$</span>2.780.964,58
# 						</h2>
#
# 						<div class="action clearfix">
# 							<p class="description">
#
# 												1 aposta ganhadora do prêmio<br> principal! Confira o
# 											resultado.
#
#
#
#
# 							</p>
# 							<p class="button">
# 								<button class="submit-d submit-orange submit-big submit-non-fluid" type="submit" onclick="pagMegaResultado();">
# 									Veja o resultado <i class="font-icon i-right-dir"></i>
# 								</button>
# 							</p>
# 						</div>
#
# </div>
# <!-- FIM mega sena -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </div>
# </div><div class="wpthemeClear"></div>
# 	</section></div>
#
# </div><div class="component-control id-Z7_61L0H0G0JOJI50AKO33UDV1010"><span id="Z7_61L0H0G0JOJI50AKO33UDV1010"></span><section class="ibmPortalControl wpthemeControl wpthemeHidden a11yRegionTarget" role="region" aria-labelledby="wpRegionIdZ7_61L0H0G0JOJI50AKO33UDV1010">
#
#
#
#
# 	<div class="asa.portlet" id="asa.portlet.Z7_61L0H0G0JOJI50AKO33UDV1010" style="display:none;">
# 		<span class="asa.portlet.id">Z7_61L0H0G0JOJI50AKO33UDV1010</span>
#
#
#
# 	</div>
#
# <!-- start header markup -->
# 	<header class="wpthemeControlHeader dojoDndHandle">
# 		<div class="wpthemeInner">
# 			<h2>
# 				<!-- lm-dynamic-title node marks location for dynamic title support -->
#  				<span class="lm-dynamic-title asa.portlet.title a11yRegionLabel" id="wpRegionIdZ7_61L0H0G0JOJI50AKO33UDV1010">Últimos resultados</span>
# 			</h2>
# 			<a aria-haspopup="true" aria-label="Menu Exibir" href="javascript:;" class="wpthemeIcon wpthemeMenuFocus" tabindex="0" onclick="wptheme.contextMenu.init(this, 'skinAction', {'navID':ibmCfg.portalConfig.currentPageOID,'windowID':wptheme.getWindowIDFromSkin(this)});">
# 				<span title="Menu Exibir"><img aria-label="Menu Exibir" alt="" src="/wps/themeModules/themes/html/dynamicSpots/icons/blank.gif"></span>
# 				<span class="wpthemeAltText">Ações</span>
# 				<span class="wpthemeMenuRight">
# 					<div class="wpthemeMenuBorder">
# 						<div class="wpthemeMenuNotchBorder"></div>
# 						<!-- define the menu item template inside the "ul" element.  only "css-class", "description", and "title" are handled by the theme's sample javascript. -->
# 						<ul class="wpthemeMenuDropDown wpthemeTemplateMenu" role="menu">
# 							<li class="${css-class}" role="menuitem" tabindex="-1"><span class="wpthemeMenuText">${title}</span></li>
# 						</ul>
# 					</div>
# 					<!-- Template for loading -->
# 					<div class="wpthemeMenuLoading wpthemeTemplateLoading">Carregando...</div>
# 					<!-- Template for submenu -->
# 					<div class="wpthemeAnchorSubmenu wpthemeTemplateSubmenu">
# 						<div class="wpthemeMenuBorder wpthemeMenuSubmenu">
# 							<ul id="${submenu-id}" class="wpthemeMenuDropDown" role="menu"><li role="menuitem" tabindex="-1"></li></ul>
# 						</div>
# 					</div>
# 				</span>
# 			</a>
# 		</div>
# 	</header>
#
# 	<div class="wpthemeControlBody wpthemeOverflowAuto wpthemeClear"> <!-- lm:control dynamic spot injects markup of layout control -->
# 	<!-- asa.overlay marks the node that the AsaOverlayWidget will be placed in -->
# 		<div style="position:relative; z-index: 1;">
# 			<div class="analytics.overlay"></div>
# 		</div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<div class="content-section section-highlight">
#     <div class="content-wrapper clearfix">
#
#         <div class="product">
#
#               <div class="dest-item"><div class="dest-Img item1"><img src="/wps/wcm/connect/21df582f-5e9a-4a0c-8a1c-3f69210f04ea/Banner-cross_370x160_02.jpg?MOD=AJPERES"></div><div class="dest-RichTxt item1"><p dir="ltr">Aposte nas Loterias Online de onde estiver. É rápido e seguro.</p>
# </div><div class="dest-link item1"><a href="https://www.loteriasonline.caixa.gov.br/silce-web/#/home?utm_source=siteLoterias&amp;utm_medium=bannercrossLoterias&amp;utm_campaign=loteriasonline&amp;utm_content=aposteja" target="_self">Clique e aposte</a></div></div>
#
#         </div>
#         <div class="product">
#
#               <div class="dest-item"><div class="dest-Img item1"><img src="/wps/wcm/connect/3b1161a5-8d49-4ef5-842b-cfd8fc664a34/jogo-responsavel.jpg?MOD=AJPERES"></div><div class="dest-RichTxt item1"><p dir="ltr">Para o jogo continuar divertido, é preciso aprender as regras.</p>
# </div><div class="dest-link item1"><a href="https://www.caixa.gov.br/jogo-responsavel/?utm_source=site_caixa&amp;utm_medium=bannercross&amp;utm_campaign=jogo_responsavel" target="_self">Seja um apostador consciente</a></div></div>
#
#         </div>
#         <div class="product">
#
#               <div class="dest-item"><div class="dest-Img item1"><img src="/wps/wcm/connect/3a6b5478-6f31-4027-806b-e1871ed4cb0e/image1_caixa_com_voce.jpg?MOD=AJPERES"></div><div class="dest-RichTxt item1"><p dir="ltr">Confira como a Caixa pode ajudar você a enfrentar este momento de desafios.</p>
# </div><div class="dest-link item1"><a href="http://www.caixa.gov.br/caixacomvoce/Paginas/default.aspx?utm_source=siteloterias&amp;utm_medium=cross&amp;utm_campaign=com_com_voce" target="none">Caixa com você</a></div></div>
#
#         </div>
#
#
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="wpthemeClear"></div>
# 	</div>
# </section>
# </div></div></div>
# <!-- this layout has two rows that go across the whole page -->
# <div class="wptheme2Col">
# 	<div class="component-container wpthemeCol content-section section-products ibmDndColumn column-left wpthemePrimaryContainer id-Z7_61L0H0G0J0E1D0AKA2JDBJ00O1" name="left"><div class="component-control id-Z7_HGK818G0K8DL20ARD3LPDT1GV7"><span id="Z7_HGK818G0K8DL20ARD3LPDT1GV7"></span><section class="ibmPortalControl wpthemeControl wpthemeHidden a11yRegionTarget" role="region" aria-labelledby="wpRegionIdZ7_HGK818G0K8DL20ARD3LPDT1GV7">
#
#
#
#
# 	<div class="asa.portlet" id="asa.portlet.Z7_HGK818G0K8DL20ARD3LPDT1GV7" style="display:none;">
# 		<span class="asa.portlet.id">Z7_HGK818G0K8DL20ARD3LPDT1GV7</span>
#
#
#
# 	</div>
#
# <!-- start header markup -->
# 	<header class="wpthemeControlHeader dojoDndHandle">
# 		<div class="wpthemeInner">
# 			<h2>
# 				<!-- lm-dynamic-title node marks location for dynamic title support -->
#  				<span class="lm-dynamic-title asa.portlet.title a11yRegionLabel" id="wpRegionIdZ7_HGK818G0K8DL20ARD3LPDT1GV7"><span lang="pt-BR" dir="ltr">SIWIC Ultimos Resultados Home</span></span>
# 			</h2>
# 			<a aria-haspopup="true" aria-label="Menu Exibir" href="javascript:;" class="wpthemeIcon wpthemeMenuFocus" tabindex="0" onclick="wptheme.contextMenu.init(this, 'skinAction', {'navID':ibmCfg.portalConfig.currentPageOID,'windowID':wptheme.getWindowIDFromSkin(this)});">
# 				<span title="Menu Exibir"><img aria-label="Menu Exibir" alt="" src="/wps/themeModules/themes/html/dynamicSpots/icons/blank.gif"></span>
# 				<span class="wpthemeAltText">Ações</span>
# 				<span class="wpthemeMenuRight">
# 					<div class="wpthemeMenuBorder">
# 						<div class="wpthemeMenuNotchBorder"></div>
# 						<!-- define the menu item template inside the "ul" element.  only "css-class", "description", and "title" are handled by the theme's sample javascript. -->
# 						<ul class="wpthemeMenuDropDown wpthemeTemplateMenu" role="menu">
# 							<li class="${css-class}" role="menuitem" tabindex="-1"><span class="wpthemeMenuText">${title}</span></li>
# 						</ul>
# 					</div>
# 					<!-- Template for loading -->
# 					<div class="wpthemeMenuLoading wpthemeTemplateLoading">Carregando...</div>
# 					<!-- Template for submenu -->
# 					<div class="wpthemeAnchorSubmenu wpthemeTemplateSubmenu">
# 						<div class="wpthemeMenuBorder wpthemeMenuSubmenu">
# 							<ul id="${submenu-id}" class="wpthemeMenuDropDown" role="menu"><li role="menuitem" tabindex="-1"></li></ul>
# 						</div>
# 					</div>
# 				</span>
# 			</a>
# 		</div>
# 	</header>
#
# 	<div class="wpthemeControlBody wpthemeOverflowAuto wpthemeClear"> <!-- lm:control dynamic spot injects markup of layout control -->
# 	<!-- asa.overlay marks the node that the AsaOverlayWidget will be placed in -->
# 		<div style="position:relative; z-index: 1;">
# 			<div class="analytics.overlay"></div>
# 		</div>
#
#
#
#
#
#
#
# <a class="top-link visible-mobile" href="#">Topo</a>
# <h2>Confira os Últimos resultados</h2>
#
#
#
#
# <style>
#  		.section-products .products .product {
#             padding: 2.5em 0;
#             min-height: 190px;
#         }
#
#         .section-products .products .product img {
#             margin-bottom: 20px
#         }
#
#         h3.nome-loteria {
#             font-size: 1.7rem;
#             font-weight: 600;
#             max-height: 40px;
#             padding-left: 49px;
#             padding-top: 4px;
#             background:
#                 url("/wps/PA_loterias-pub/images/icos_loterias.png")
#                 no-repeat;
#         }
#
#         h3.megasena {
#             background-position: left top;
#             color: #209869;
#         }
#
#         h3.lotofacil {
#             background-position: left -45px;
#             color: #930089;
#         }
#
#         h3.quina {
#             background-position: left -91px;
#             color: #260085;
#         }
#
#         h3.lotomania {
#             background-position: left -136px;
#             color: #f78100;
#         }
#
#         h3.timemania {
#             background-position: left -181px;
#             color: #00ff48;
#         }
#
#         h3.duplasena {
#             background-position: left -225px;
#             color: #a61324;
#         }
#
#         h3.federal {
#             background-position: left -269px;
#             color: #103099;
#         }
#
#         h3.loteca {
#             background-position: left -316px;
#             color: #fb1f00;
#         }
#
#         h3.lotogol {
#             background-position: left -361px;
#             color: #0086b7;
#         }
#
#         h3.instantanea {
#             background-position: left -361px;
#             color: #0086b7;
#         }
#
#         h3.diadesorte {
#             background-position: left -403px;
#             color: #cb852b;
#         }
#         h3.supersete {
#           background-position: left -446px;
#           color: #a8cf45;
#         }
#         .section-products .product .resultado-loteria.diadesorte > li {
#                background: #cb852b;
#         }
#         .section-products .product .resultado-loteria.duplasena > li {
#             background: #BF194E;
#         }
#         .section-products .product .resultado-loteria.quina > li {
#             background: #260085;
#         }
#         .section-products .product .resultado-loteria.timemania > li {
#             color:#049645;
#             background: #FFF600;
#         }
#         .section-products .product .resultado-loteria.supersete > li {
#             color: #4c546d;
#             background: #a8cf45;
#         }
#         .section-products .product .resultado-loteria.supersete{
#             margin: 10px 0 40px 0;
#             height: 100px;
#         }
#         .m-top-30{
#             margin-top: 30px;
#         }
#         .section-products .product .resultado-loteria.supersete > li {
#           display: inline-block;
#           margin: 3px;
#           font-family: "FuturaWeb",sans-serif;
#           font-size: 1.1rem;
#           color: #4c546d;
#           background: none;
#           border-radius: 0;
#           width: 45px;
#           height: 45px;
#           padding: 5px 0;
#           text-align: center;
#         }
#         .section-products .product .resultado-loteria.supersete > li div.coluna{
#             display: inline-block;
#             margin: 3px;
#             font-family: "FuturaWeb",sans-serif;
#             font-size: 1.1rem;
#             color: #4c546d;
#             background: none;
#             border-radius: 35px;
#             width: 45px;
#             height: 45px;
#             padding: 9px 0;
#             text-align: center;
#             font-weight: 600;
#         }
#         .section-products .product .resultado-loteria.supersete > li div.dezena{
#             display: inline-block;
#             margin: 3px;
#             font-family: "FuturaWeb",sans-serif;
#             font-size: 1.1rem;
#             color: #4c546d;
#             background: #a8cf45;
#             border-radius: 35px;
#             width: 45px;
#             height: 45px;
#             padding: 9px 0;
#             text-align: center;
#             font-weight: 600;
#         }
#
#         @media screen and (min-width: 600px) and (max-width: 700px) {
#             .section-products .product .resultado-loteria.supersete > li {
#                 margin: 1px;
#                 width: 40px;
#                 height: 40px;
#             }
#             .section-products .product .resultado-loteria.supersete > li div.coluna{
#                 margin: 0px;
#                 width: 42px;
#                 height: 45px;
#             }
#             .section-products .product .resultado-loteria.supersete > li div.dezena{
#                 margin: 0px;
#                 width: 42px;
#                 height: 42px;
#             }
#         }
#         @media screen and (max-width: 400px) {
#             .section-products .product .resultado-loteria.supersete > li {
#                 margin: 1px;
#                 width: 35px;
#                 height: 35px;
#             }
#             .section-products .product .resultado-loteria.supersete > li div.coluna{
#                 margin: 0px;
#                 width: 35px;
#                 height: 38px;
#             }
#             .section-products .product .resultado-loteria.supersete > li div.dezena{
#                 margin: 0px;
#                 width: 35px;
#                 height: 35px;
#                 font-size: 1rem;
#                 padding: 7px 0;
#             }
#         }
# </style>
#
# 	<div class="products">
# 		<div class="product no-title clearfix">
# 			<div class="product-column">
#
# 				<h3 class="megasena nome-loteria">MEGA-SENA</h3>
# 			</div>
# 			<div class="product-column">
# 				<ul class="resultado-loteria mega-sena"><li>05</li><li>10</li><li>25</li><li>32</li><li>49</li><li>54</li>
# 				</ul>
#
#
#
#
# 						<h3 class="zeta">
# 							<a href="/wps/portal/loterias/landing/megasena">1 GANHADOR</a>:
# 							R$ 2.780.964,58
# 						</h3>
#
#
#
#
# 				<p class="description">Concurso 2349 - Quarta-feira, 3 de Março de 2021</p>
# 				<p class="see-more">
# 					<a href="/wps/portal/loterias/landing/megasena">Confira o
# 						resultado ›</a>
# 				</p>
# 			</div>
# 		</div>
# 		<div class="product clearfix">
# 			<div class="product-column">
#
# 				<h3 class="lotofacil nome-loteria">LOTOFÁCIL</h3>
# 			</div>
# 			<div class="product-column">
# 				<table class="simple-table lotofacil">
# 					<thead>
# 					</thead>
# 					<tbody>
#
#
# 								<tr>
#
# 							<td>06</td>
#
#
#
# 							<td>08</td>
#
#
#
# 							<td>09</td>
#
#
#
# 							<td>10</td>
#
#
#
# 							<td>11</td>
#
# 								</tr>
#
#
#
# 								<tr>
#
# 							<td>13</td>
#
#
#
# 							<td>14</td>
#
#
#
# 							<td>15</td>
#
#
#
# 							<td>16</td>
#
#
#
# 							<td>17</td>
#
# 								</tr>
#
#
#
# 								<tr>
#
# 							<td>19</td>
#
#
#
# 							<td>20</td>
#
#
#
# 							<td>22</td>
#
#
#
# 							<td>23</td>
#
#
#
# 							<td>25</td>
#
# 								</tr>
#
#
# 					</tbody>
# 				</table>
#
#
#
#
#
#
# 						<h3 class="zeta">
# 							<a href="/wps/portal/loterias/landing/lotofacil">3
# 								GANHADORES</a>
# 						</h3>
#
#
# 				<p class="description">Concurso 2172 -
# 					Quinta-feira, 4 de Março de 2021</p>
# 				<p class="see-more">
# 					<a href="/wps/portal/loterias/landing/lotofacil">Confira o
# 						resultado ›</a>
# 				</p>
# 			</div>
# 		</div>
# 		<div class="product clearfix">
# 			<div class="product-column">
#
# 				<h3 class="quina nome-loteria">QUINA</h3>
# 			</div>
# 			<div class="product-column">
# 				<ul class="resultado-loteria quina"><li>23</li><li>27</li><li>54</li><li>59</li><li>60</li>
# 				</ul>
#
#
#
#
#
# 						<h3 class="zeta">
# 							<a href="/wps/portal/loterias/landing/quina">ACUMULOU!</a>
# 						</h3>
#
#
#
#
# 				<p class="description">Concurso 5506 - Quinta-feira, 4 de Março de 2021</p>
# 				<p class="see-more">
# 					<a href="/wps/portal/loterias/landing/quina">Confira o
# 						resultado ›</a>
# 				</p>
# 			</div>
# 		</div>
# 		<div class="product clearfix">
# 			<div class="product-column">
#
# 				<h3 class="lotomania nome-loteria">LOTOMANIA</h3>
# 			</div>
# 			<div class="product-column">
# 				<table class="simple-table lotomania">
# 					<thead>
# 					</thead>
# 					<tbody>
#
#
# 							<tr>
#
# 						<td>00</td>
#
#
#
# 						<td>04</td>
#
#
#
# 						<td>08</td>
#
#
#
# 						<td>10</td>
#
#
#
# 						<td>17</td>
#
# 							</tr>
#
#
#
# 							<tr>
#
# 						<td>19</td>
#
#
#
# 						<td>20</td>
#
#
#
# 						<td>21</td>
#
#
#
# 						<td>30</td>
#
#
#
# 						<td>34</td>
#
# 							</tr>
#
#
#
# 							<tr>
#
# 						<td>41</td>
#
#
#
# 						<td>48</td>
#
#
#
# 						<td>60</td>
#
#
#
# 						<td>62</td>
#
#
#
# 						<td>72</td>
#
# 							</tr>
#
#
#
# 							<tr>
#
# 						<td>79</td>
#
#
#
# 						<td>88</td>
#
#
#
# 						<td>91</td>
#
#
#
# 						<td>95</td>
#
#
#
# 						<td>96</td>
#
# 							</tr>
#
#
# 					</tbody>
# 				</table>
#
#
#
#
#
# 						<h3 class="zeta">
# 							<a href="/wps/portal/loterias/landing/lotomania">1 GANHADOR</a>
# 						</h3>
#
#
#
# 				<p class="description">Concurso 2157 -
# 					Terça-feira, 2 de Março de 2021</p>
# 				<p class="see-more">
# 					<a href="/wps/portal/loterias/landing/lotomania">Confira o
# 						resultado ›</a>
# 				</p>
# 			</div>
# 		</div>
# 		<div class="product clearfix">
# 			<div class="product-column">
#
# 				<h3 class="timemania nome-loteria">TIMEMANIA</h3>
# 			</div>
# 			<div class="product-column">
# 				<ul class="resultado-loteria timemania"><li>13</li><li>32</li><li>33</li><li>36</li><li>37</li><li>68</li><li>79</li></ul>
#
#
#
#
# 						<h3 class="zeta">
# 							<a href="/wps/portal/loterias/landing/timemania">ACUMULOU!</a>
# 						</h3>
#
#
#
#
# 				<p class="description">Concurso 1608 -
# 					Quinta-feira, 4 de Março de 2021</p>
# 				<p class="see-more">
# 					<a href="/wps/portal/loterias/landing/timemania">Confira o
# 						resultado ›</a>
# 				</p>
# 			</div>
# 		</div>
# 		<div class="product clearfix">
# 			<div class="product-column">
#
# 				<h3 class="duplasena nome-loteria">DUPLA SENA</h3>
# 			</div>
# 			<div class="product-column">
# 				<h4>1º sorteio</h4>
# 				<ul class="resultado-loteria duplasena"><li>05</li><li>11</li><li>32</li><li>39</li><li>45</li><li>50</li></ul>
# 				<h4>2º sorteio</h4>
# 				<ul class="resultado-loteria duplasena"><li>23</li><li>25</li><li>30</li><li>33</li><li>42</li><li>46</li></ul>
#
#
#
# 						<h3 class="zeta">
# 							<a href="/wps/portal/loterias/landing/duplasena">ACUMULOU!</a>
# 						</h3>
#
#
#
#
#
#
# 				<p class="description">Concurso 2203 - Quinta-feira, 4 de Março de 2021</p>
# 				<p class="see-more">
# 					<a href="/wps/portal/loterias/landing/duplasena">Confira o resultado ›</a>
# 				</p>
# 			</div>
# 		</div>
#  		<div class="product clearfix federal">
# 			<div class="product-column">
# 				<!-- <img src="/wps/PA_loterias-pub/images/logo_federal_gde.png" alt="Federal"> -->
# 				<h3 class="federal nome-loteria">FEDERAL</h3>
# 			</div>
# 			<div class="product-column">
# 				<h4>Prêmios Principais</h4>
#
# 					<p class="description">Sorteio Realizado
# 						em SAO PAULO, SP, .</p>
#
# 				<table class="simple-table resultado-table three-column-table">
# 					<thead>
# 						<tr>
# 							<th>Destino</th>
# 							<th>Bilhete</th>
# 							<th>Valor do Prêmio (R$)</th>
# 						</tr>
# 					</thead>
# 					<tbody>
# 						<tr>
# 							<td>1º</td>
# 							<td>028040</td>
# 							<td>500.000,00</td>
# 						</tr>
# 						<tr>
# 							<td>2º</td>
# 							<td>020530</td>
# 							<td>27.000,00</td>
# 						</tr>
# 						<tr>
# 							<td>3º</td>
# 							<td>043409</td>
# 							<td>24.000,00</td>
# 						</tr>
# 						<tr>
# 							<td>4º</td>
# 							<td>007780</td>
# 							<td>19.000,00</td>
# 						</tr>
# 						<tr>
# 							<td>5º</td>
# 							<td>009047</td>
# 							<td>18.329,00</td>
# 						</tr>
# 					</tbody>
# 				</table>
# 				<p class="description">Concurso 5543 -
# 					Quarta-feira, 3 de Março de 2021</p>
# 				<p class="see-more">
# 					<a href="/wps/portal/loterias/landing/federal">Confira o
# 						resultado ›</a>
# 				</p>
# 			</div>
# 		</div>
#
# 		<div class="product clearfix">
# 			<div class="product-column">
#
# 				<h3 class="loteca nome-loteria">LOTECA</h3>
# 			</div>
# 			<div class="product-column">
# 				<table class="table-d loteca hidden-mobile">
# 					<thead>
# 					<tr>
# 						<th>Jogo</th>
# 						<th colspan="2">Coluna 1</th>
# 						<th>x</th>
# 						<th colspan="2">Coluna 2</th>
# 						<th>Data</th>
# 					</tr>
# 					</thead>
# 					<tbody>
#
# 						<tr>
# 							<td>1</td>
#
#
# 									<td class="selected">2</td>
# 									<td><span style="text-transform: capitalize;">vitoria          /BA</span></td>
# 									<td>&nbsp;</td>
# 									<td><span style="text-transform: capitalize;">santa cruz       /PE</span></td>
# 									<td>0</td>
#
#
#
#
#
#
# 									<td><span style="text-transform: capitalize;"> Sáb&nbsp;
# 									</span></td>
#
#
#
#
# 						</tr>
#
# 						<tr>
# 							<td>2</td>
#
#
#
#
# 									<td>1</td>
# 									<td><span style="text-transform: capitalize;">verona           /</span></td>
# 									<td class="selected">&nbsp;</td>
# 									<td><span style="text-transform: capitalize;">juventus         /  </span></td>
# 									<td>1</td>
#
#
#
#
# 									<td><span style="text-transform: capitalize;"> Sáb&nbsp;
# 									</span></td>
#
#
#
#
# 						</tr>
#
# 						<tr>
# 							<td>3</td>
#
#
#
#
# 									<td>1</td>
# 									<td><span style="text-transform: capitalize;">novorizontino    /</span></td>
# 									<td class="selected">&nbsp;</td>
# 									<td><span style="text-transform: capitalize;">ponte preta      /SP</span></td>
# 									<td>1</td>
#
#
#
#
# 									<td><span style="text-transform: capitalize;"> Sáb&nbsp;
# 									</span></td>
#
#
#
#
# 						</tr>
#
# 						<tr>
# 							<td>4</td>
#
#
#
#
# 									<td>0</td>
# 									<td><span style="text-transform: capitalize;">rb bragantino    /</span></td>
# 									<td class="selected">&nbsp;</td>
# 									<td><span style="text-transform: capitalize;">corinthians      /SP</span></td>
# 									<td>0</td>
#
#
#
#
# 									<td><span style="text-transform: capitalize;"> Dom&nbsp;
# 									</span></td>
#
#
#
#
# 						</tr>
#
# 						<tr>
# 							<td>5</td>
#
#
#
#
# 									<td>2</td>
# 									<td><span style="text-transform: capitalize;">santo andre      /</span></td>
# 									<td class="selected">&nbsp;</td>
# ...
#                         <li><a title="Sobre a Caixa" href="http://www.caixa.gov.br/sobre-a-caixa/">Sobre a Caixa</a></li>
#                 		<li><a title="Trabalhe na Caixa" href="http://www.caixa.gov.br/sobre-a-caixa/trabalhe-na-caixa">Trabalhe na Caixa</a></li>
#                 		<li><a title="Canal de Denúncia" href="http://www.caixa.gov.br/atendimento/canal-denuncia/Paginas/default.aspx">Canal de Denúncia</a></li>
#                 		<li><a title="Caixa de A - Z" href="http://www.caixa.gov.br/caixa-a-z/Paginas/default.aspx">Caixa de A - Z</a></li>
#                 		<li><a title="Promoções" href="http://www.caixa.gov.br/voce/promocoes/Paginas/default.aspx">Promoções</a></li>
#                     </ul>
#                 </div>
#
#                 <div class="footer-column">
#                     <ul>
#                         <li><a href="https://www.twitter.com/caixa"><i class="icon fa fa-twitter fa-1x"></i> Twitter</a></li>
#                         <li><a href="https://www.facebook.com/caixa"><i class="icon fa fa-facebook fa-1x"></i> Facebook</a></li>
#                         <li><a href="https://www.youtube.com/canalcaixa"><i class="icon fa fa-youtube-play fa-1x"></i> Youtube</a></li>
#                         <li><a href="https://www.instagram.com/caixa"><i class="icon fa fa-instagram fa-1x"></i> Instagram</a></li>
#                     </ul>
#                 </div>
#             </div>
#
#             <div class="hotlinks clearfix">
#                 <ul class="languages">
#                     <li><a href="http://www.caixa.gov.br/site/english/">English</a></li>
#                 </ul>
#
#                 <ul>
#                     <li><a href="http://www.caixa.gov.br/atendimento">Ouvidoria</a></li>
#                     <li><a href="http://www.caixa.gov.br/politica-de-privacidade">Política de Privacidades</a></li>
#                     <li><a href="http://www.caixa.gov.br/termos-de-uso/">Termos de Uso</a></li>
#                 </ul>
#                 <ul>
#                     <li><a href="http://www.caixa.gov.br/seguranca">Segurança</a></li>
#                     <li><a href="https://caixanoticias.caixa.gov.br">Caixa Notícias</a></li>
#                     <li><a style="display:none" href="#main-logo">Caixa</a></li>
#                 </ul>
# <ul class="ainfo">
#                     <li><a href="http://www.caixa.gov.br/acesso-a-informacao/Paginas/default.aspx"><img style="float:right" src="/wps/wcm/connect/ba449861-d64f-4636-aa1f-2788c6a5b779/ainfo.png?MOD=AJPERES&amp;CACHEID=ba449861-d64f-4636-aa1f-2788c6a5b779" width="99" height="44" title="acesso à informação" alt="acesso à informação"></a></li>
#                 </ul>
#             </div>
# <link title="" rel="stylesheet" type="text/css" href="/wps/wcm/connect/bbde5c91-3572-4666-b81b-e208b3e319a9/novoCss_loterias.css?MOD=AJPERES&amp;CACHEID=bbde5c91-3572-4666-b81b-e208b3e319a9">
# </footer>
#
#
# 	<!-- end frame -->
#
# 	<!-- This is responsible for bootstrapping the configuration for the javascript framework.
#         This is located here instead of the head section to improve client performance. -->
# 	<div class="wpthemeComplementaryContent" id="wpthemeComplementaryContent" role="region" aria-labelledby="wpthemeComplementaryContentText">
# 		<span class="wpthemeAltText" id="wpthemeComplementaryContentText">
# 			Complementary Content
# 		</span>
# 		<script type="text/javascript" src="/wps/contenthandler/!ut/p/digest!zpGlEiidBQ-1ajPSpjP1Pg/mashup/ra:collection?themeID=ZJ_61L0H0G0J03540AI77QD5F3OV7&amp;locale=pt-BR&amp;locale=pt&amp;locale=en&amp;mime-type=text%2Fplain&amp;entry=wp_asa_module_path__0.0%3Aconfig_config_static&amp;entry=wp_portal_client_module_path__0.0%3Aconfig_config_static&amp;entry=mm_enabler__0.0%3Aconfig_config_static&amp;entry=wp_pagebuilder_module_path__0.0%3Aconfig_config_static&amp;entry=wcm_config__0.0%3Aconfig_config_static&amp;entry=wp_contentmapping_module_path__0.0%3Aconfig_config_static&amp;entry=wcm_inplaceEdit__0.0%3Aconfig_config_static&amp;entry=wp_portal__0.0%3Aconfig_config_static&amp;entry=wp_federation_module_path__0.0%3Aconfig_config_static"></script><script type="text/javascript">i$.merge({"ibmCfg":{"enablerConfig":{"com.ibm.mashups.proxy.url":"/wps/proxy","com.ibm.mashups.productname":"IBM WebSphere Portal","com.ibm.mashups.anonymous.mode":"true","serviceDocumentUrl":"/wps/contenthandler/!ut/p/digest!fIP8xD7BGS9_AUr2Kvs2Uw/model/service-document/?locale=pt-br","anonymousUser":true,"user":null,"fontSizeEnlarged":false,"isBidi":false,"locale":"pt-br","displayLocale":"pt-br","com.ibm.mashups.contextroot":"/wps","defaultLayoutTemplateURI":"war:InstitucionalTema/themes/static/layout-templates/2ColumnEqual/","com.ibm.mashups.contenthandler.private":"/wps/mycontenthandler/!ut/p/digest!fIP8xD7BGS9_AUr2Kvs2Uw/","com.ibm.mashups.contenthandler.public":"/wps/contenthandler/!ut/p/digest!fIP8xD7BGS9_AUr2Kvs2Uw/"}},"portalMashupsConfig":{"serviceDocURL":"/wps/contenthandler/!ut/p/digest!fIP8xD7BGS9_AUr2Kvs2Uw/model/service-document/?locale=pt-br","contentHandlerContextPath":"/wps/contenthandler/!ut/p/digest!fIP8xD7BGS9_AUr2Kvs2Uw/"}});
# 	var ibmPortalCPConfig=null;
#
#
#
# var SemTagSvcPortalGlobalDynamic={
# basePumaResolvedUrl: ''+
# ''+
# '/wps/contenthandler/!ut/p/digest!fIP8xD7BGS9_AUr2Kvs2Uw/um/secure/users/profiles?locale=pt_BR',
# availAttribUrl: ''+
# ''+
# '/wps/contenthandler/!ut/p/digest!fIP8xD7BGS9_AUr2Kvs2Uw/um/secure/attributes/users?locale=pt_BR'
# };
# i$.merge({"ibmCfg":{"themeConfig":{"themeUniqueName":"caixa.portal.InstitucionalTema","themeRootURI":"/wps/contenthandler/!ut/p/digest!uIZ73NkcnEbqYuA2ytc-bg/war/InstitucionalTema/themes/static","themeWebAppBaseURI":"/InstitucionalTema/themes/html/dynamicSpots","themeWebDAVBaseURI":"war:InstitucionalTema/themes/static/","modulesWebAppBaseURI":"/wps/themeModules","commonResourcesRootURI":"/wps/contenthandler/!ut/p/digest!MiKaaGl25m2KN1Xf4hY5bg/dav/fs-type1/common-resources","isRTL":false,"isPageRenderModeCSA":false,"portletOverridePageTitle":"Loterias | Caixa","currentContentNodeOID":"Z6_61L0H0G0JGPC50AODB90303005","loadingImage":"css/images/loading.gif","dndSourceDefinitions":[{"id":"ibmDndColumn","object":"com.ibm.pb.dnd.layout.LayoutColumnSource","orientation":"vertical"},{"id":"ibmDndRow","object":"com.ibm.pb.dnd.layout.LayoutRowSource","orientation":"horizontal"}],"categorySources":[],"styleSources":[],"layoutSources":[]},"portalConfig":{"locale":"pt-br","portalURI":"/wps/portal","contentHandlerURI":"/wps/contenthandler/!ut/p/digest!fIP8xD7BGS9_AUr2Kvs2Uw/","isVirtualPortal":false,"canImpersonate":false,"themeRootURI":"/InstitucionalTema/themes/html/dynamicSpots","parentPageID":"Z6_CGAH47L0004820IDBHD79M00I6","currentPageOID":"Z6_61L0H0G0JGPC50AODB90303005","bootstrapState":"&lt;?xml version=&#034;1.0&#034; encoding=&#034;UTF-8&#034;?&gt;&lt;root xmlns=&#034;http://www.ibm.com/xmlns/prod/websphere/portal/v6.1/portal-state&#034;&gt;&lt;state type=&#034;navigational&#034;&gt;&lt;selection selection-node=&#034;Z6_61L0H0G0JGPC50AODB90303005&#034;&gt;&lt;mapping src=&#034;Z6_000000000000000000000000A0&#034; dst=&#034;Z6_61L0H0G0JGPC50AODB90303005&#034;/&gt;&lt;/selection&gt;&lt;expansions&gt;&lt;node id=&#034;Z6_CGAH47L0004820IDBHD79M00I6&#034;/&gt;&lt;node id=&#034;Z6_000000000000000000000000A0&#034;/&gt;&lt;/expansions&gt;&lt;/state&gt;&lt;/root&gt;","isUserLoggedIn":false,"currentUser":"anonymous portal user","currentUserOID":"","aggregatedStyle":null,"wcmPageMetadata":{"contentRoot":null,"sharingScope":"ibm.wcm.0.1391525776339"}},"userName":""},"com_ibm_theme_capabilities":{"analytics_aggregator":"8.0","hasBaseURL":"true","oneUI":"3.0.1"}});ibmCfg.portalConfig.bootstrapState=(ibmCfg.portalConfig.bootstrapState||"").replace(/&lt;/gm, '<').replace(/&gt;/gm, '>').replace(/&amp;/gm, '&').replace(/&#039;/gm, "'").replace(/&#034;/gm, '"');
# (function(){ibmToolbarConfig = {projectUUID: "",toolbarMode: "closed",inManagedPages: "true"==="true",isPrivilegedUser: "false"==="true",hasEditSharedPermission: "false"==="true",dialogJavascriptURL: "/wps/contenthandler/!ut/p/digest!uIZ73NkcnEbqYuA2ytc-bg/dialog/dialogModal.js",dialogUtilsJavascriptURL: "/wps/contenthandler/!ut/p/digest!uIZ73NkcnEbqYuA2ytc-bg/dialog/dialogModalUtils.js",draftPageUUID: ""
# 	}})();
#
# ibmCfg.portalConfig.asaConfig = {canViewAsaReports: "false",canViewAsaSitePromotions: "false",canCreateAsaSitePromotions: "false",canDeleteAsaSitePromotions: "false",reportConfig: {"scopes":[]}
# };</script><script type="text/javascript" src="/wps/contenthandler/!ut/p/digest!uIZ73NkcnEbqYuA2ytc-bg/mashup/ra:collection?themeID=ZJ_61L0H0G0J03540AI77QD5F3OV7&amp;locale=pt-BR&amp;locale=pt&amp;locale=en&amp;mime-type=text%2Fplain&amp;entry=wp_one_ui_30__0.0%3Aconfig_js&amp;entry=wp_theme_menus__0.0%3Aconfig_js&amp;entry=wp_theme_skin_region__0.0%3Aconfig_js&amp;entry=wp_ic4_wai_resources__0.0%3Aconfig_js&amp;entry=wp_theme_high_contrast__0.0%3Aconfig_js&amp;entry=wp_theme_edit__0.0%3Aconfig_js&amp;entry=wp_status_bar__0.0%3Aconfig_js"></script><a rel="alternate" id="config_js_deferred" href="/wps/contenthandler/!ut/p/digest!MiKaaGl25m2KN1Xf4hY5bg/mashup/ra:collection?themeID=ZJ_61L0H0G0J03540AI77QD5F3OV7&amp;locale=pt-BR&amp;locale=pt&amp;locale=en&amp;mime-type=text%2Fplain&amp;entry=wp_portal_client_rest_utils__0.0%3Aconfig_js&amp;entry=mm_enabler__0.0%3Aconfig_js&amp;entry=mm_builder__0.0%3Aconfig_js&amp;entry=wp_tagging_rating__0.0%3Aconfig_js&amp;entry=wp_pagebuilder_base__0.0%3Aconfig_js&amp;entry=wp_pagebuilder_ui__0.0%3Aconfig_js&amp;entry=mm_new_page_dialog__0.0%3Aconfig_js&amp;entry=mm_builder_dialogs__0.0%3Aconfig_js&amp;entry=mm_page_sharing_base__0.0%3Aconfig_js&amp;entry=mm_page_sharing_permission__0.0%3Aconfig_js&amp;entry=wp_wcm_modal_dialog__0.0%3Aconfig_js&amp;entry=wp_portal_ui_utils__0.0%3Aconfig_js&amp;entry=wp_content_mapping_picker__0.0%3Aconfig_js&amp;entry=wp_dialog_main__0.0%3Aconfig_js&amp;entry=wp_contextmenu_js__0.0%3Aconfig_js&amp;entry=wp_liveobject_framework__0.0%3Aconfig_js&amp;entry=wp_contextmenu_live_object__0.0%3Aconfig_js&amp;entry=wp_content_targeting_cam__0.0%3Aconfig_js&amp;entry=mm_delete_control__0.0%3Aconfig_js&amp;entry=mm_delete_page__0.0%3Aconfig_js&amp;entry=wp_managed_pages_support_edit__0.0%3Aconfig_js&amp;entry=wp_federated_documents_picker__0.0%3Aconfig_js&amp;entry=wp_template_select_dialog__0.0%3Aconfig_js&amp;entry=wp_pagebuilder_data__0.0%3Aconfig_js&amp;entry=wp_pagebuilder_dnd__0.0%3Aconfig_js&amp;entry=mm_move_page__0.0%3Aconfig_js&amp;entry=wp_pagebuilder_controls__0.0%3Aconfig_js&amp;entry=wp_pagebuilder_shelf_base__0.0%3Aconfig_js&amp;entry=wp_analytics__0.0%3Aconfig_js&amp;entry=wp_theme_widget__0.0%3Aconfig_js&amp;entry=mm_builder_wiring__0.0%3Aconfig_js&amp;deferred=true" style="display:none"></a><a rel="alternate" id="config_markup_deferred" href="/wps/contenthandler/!ut/p/digest!uIZ73NkcnEbqYuA2ytc-bg/mashup/ra:collection?themeID=ZJ_61L0H0G0J03540AI77QD5F3OV7&amp;locale=pt-BR&amp;locale=pt&amp;locale=en&amp;mime-type=text%2Fplain&amp;entry=wp_contextmenu_templates__0.0%3Aconfig_markup&amp;entry=mm_new_page_dialog__0.0%3Aconfig_markup&amp;entry=mm_page_sharing_base__0.0%3Aconfig_markup&amp;entry=wp_template_select_dialog__0.0%3Aconfig_markup&amp;entry=mm_move_page__0.0%3Aconfig_markup&amp;entry=mm_builder_wiring__0.0%3Aconfig_markup&amp;deferred=true" style="display:none"></a></div>
# 	<!-- Piwik -->
# 	<script type="text/javascript">
# 		var _paq = _paq || [];
# 		_paq.push(["setCookieDomain", "*.caixa.gov.br"]);
# 		_paq.push(["setDomains", ["*.caixa.gov.br","*.www.caixa.gov.br","*.loterias.caixa.gov.br","*.faleconosco.caixa.gov.br","*.fale-conosco.caixa.gov.br","mcmv.caixa.gov.br","www.melhorespraticas.caixa.gov.br"]]);
# 		_paq.push(['setCustomUrl', location.href.toLowerCase()]);
# 		_paq.push(['trackPageView']);
# 		_paq.push(['enableLinkTracking']);
# 		(function() {
# 		var u=(("https:" == document.location.protocol) ? "https" : "http") + "://ew.caixa.gov.br/piwik/";
# 		_paq.push(['setTrackerUrl', u+'piwik.php']);
# 		_paq.push(['setSiteId', 4]);
# 		var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0]; g.type='text/javascript';
# 		g.defer=true; g.async=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
# 		})();
# 	</script>
# 	<noscript>
# 		<p>
# 			<img src="http://ew.caixa.gov.br/piwik/piwik.php?idsite=4"
# 				style="border: 0;" alt="PIWIK" />
# 		</p>
# 	</noscript>
# 	<!-- End Piwik Code -->
#
# 	<!-- Google Tag Manager -->
# 	<noscript>
# 		<iframe src="//www.googletagmanager.com/ns.html?id=GTM-NDBHSL"
# 			height="0" width="0" style="display: none; visibility: hidden"></iframe>
# 	</noscript>
# 	<script>
# 		(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NDBHSL');
# 	</script>
# 	<!-- End Google Tag Manager -->
#
# 	<!-- Begin App Insights -->
#     <script type="text/javascript">
#         //<![CDATA[
#         var appInsights = window.appInsights || function (config) {
#             function r(config) { t[config] = function () { var i = arguments; t.queue.push(function () { t[config].apply(t, i) }) } }
#             var t = { config: config }, u = document, e = window, o = "script", s = u.createElement(o), i, f; s.src = config.url || "//az416426.vo.msecnd.net/scripts/a/ai.0.js"; u.getElementsByTagName(o)[0].parentNode.appendChild(s); try { t.cookie = u.cookie } catch (h) { }
#             for (t.queue = [], i = ["Event", "Exception", "Metric", "PageView", "Trace", "Dependency"]; i.length;)
#                 r("track" + i.pop()); return r("setAuthenticatedUserContext"), r("clearAuthenticatedUserContext"), config.disableExceptionTracking || (i = "onerror", r("_" + i), f = e[i], e[i] = function (config, r, u, e, o) { var s = f && f(config, r, u, e, o); return s !== !0 && t["_" + i](config, r, u, e, o), s }), t
#         }
#         ({ instrumentationKey: "0550b64f-b545-421f-a7da-9e3efc083358", overridePageViewDuration: true }); window.appInsights = appInsights; $(document).ready(function () { appInsights.trackPageView(null, null, { appName: "SIWIC.LOTERIAS", appVersion: "1.0", urlReferrer: document.referrer, "screenResolution": screen.width + "x" + screen.height }); });
#         //]]></script>
# 	<!-- End App Insights -->
#
#
#
#
# <!-- Versao do Tema: 1.1.0 -->
# <!-- Node DisplayName: WebSphere_Portal -->
#
#
# <script type="text/javascript" id="" src="https://platform.twitter.com/oct.js"></script>
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","//connect.facebook.net/en_US/fbevents.js");fbq("init","906773689444391");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=906773689444391&amp;ev=PageView&amp;noscript=1"></noscript>
#
# <script type="text/javascript" id="">twttr.conversion.trackPid("nu8jp",{tw_sale_amount:0,tw_order_quantity:0});</script>
# <noscript>
# <img height="1" width="1" style="display:none;" alt="" src="https://analytics.twitter.com/i/adsct?txn_id=nu8jp&amp;p_id=Twitter&amp;tw_sale_amount=0&amp;tw_order_quantity=0">
#   <img height="1" width="1" style="display:none;" alt="" src="https://t.co/i/adsct?txn_id=nu8jp&amp;p_id=Twitter&amp;tw_sale_amount=0&amp;tw_order_quantity=0">
# </noscript><script src="https://analytics.twitter.com/i/adsct?type=javascript&amp;version=1.1.0&amp;p_id=Twitter&amp;p_user_id=0&amp;txn_id=nu8jp&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=http%3A%2F%2Floterias.caixa.gov.br%2Fwps%2Fportal%2Floterias%2F" type="text/javascript"></script>
# Terminei a raspagem de dados
