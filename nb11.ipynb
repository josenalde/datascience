# %% [markdown]
# ### Prof. Josenalde Oliveira@TADS-UFRN - Fundamentos e Técnicas em Ciências de Dados
#
# #### CRUD em mongoDB: vamos aplicar os métodos básicos de inserção, atualização e remoção de documentos. Os métodos de atualização e remoção usualmente envolvem expressões de busca (find), portanto os exemplos abaixo procuram explorar as combinações de operadores de busca, para familiarização e referência básica de comandos para aplicação nos casos e problemas que venham a surgir. Usaremos a importação do arquivo CSV no mongoDB com os resultados da megasena para nossos exemplos.
#
# #### Assumimos que o arquivo já encontra-se importado no mongoDB, no banco concursos, coleção megasena.
#
# ##### <span style="color:blue">1) vamos conectar ao mongodb server rodando localmente na máquina, acessar o banco concursos e a coleção megasena. Em seguida, vamos obter o número de documentos, com o método</span> <code>count()<code>

# %%
from pymongo import MongoClient

localConn = MongoClient('mongodb://127.0.0.1:27017')

# selecionar banco
db = localConn.concursos 
# acessar collection (equivalente a uma tabela no relacional), onde os documentos estão armazenados
tb = db.megasena # ou revisores = db['listingsAndReviews']

# obter quantidade de documentos (count() já está antigo, usar count_documents({}). Dentro das chaves é possível passar filtros)
# apenas {} retorna todos os documentos
print('Quantidade de documentos: ' + str(tb.count_documents({}))) # foi feito o typecast com str para concatenar no print
# Out:
# Quantidade de documentos: 2429

# %% [markdown]
# ##### <span style="color:blue">2) uma descrição estatística geral sobre a coleção pode ser obtida com o método stats(), ![mongo](mongocrud1.png), executado a partir do shell (como Robo3T). Aqui, se usado apenas stats (sem os parênteses), retorna a informação abaixo</span>

# %%
db['megasena'].stats
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'concursos'), 'megasena.stats')

# %% [markdown]
# ##### <span style="color:blue">3) Busca: para trazer apenas o primeiro registro, <code>find_one({})></code>; para trazer todos, apenas <code>find({})</code>. Existem algumas diferenças nos nomes de métodos, entre o uso no pymongo e o uso direto no shell. Por exemplo, find_one (pymongo) e findOne no shell ![](mongocrud2.png). No python, find_one e find retornam cursores, os quais devem ser atribuídos a listas para visualização e manipulação</span>

# %%
print('----- Apenas o primeiro, sem critérios de busca -----')
d1 = list(tb.find_one({}))
d1
print('----- trazendo todos, mostra por default os 20 primeiros -----')
dall = list(tb.find({}))
dall
# Out:
# ----- Apenas o primeiro, sem critérios de busca -----
# ----- trazendo todos, mostra por default os 20 primeiros -----
# [{'_id': ObjectId('602d3e5c6980848c48ba6e58'),
#   '': '0',
#   'Concurso': '1',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-03-11',
#   'Coluna 1': '4',
#   'Coluna 2': '5',
#   'Coluna 3': '30',
#   'Coluna 4': '33',
#   'Coluna 5': '41',
#   'Coluna 6': '52',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '17',
#   'Ganhadores Faixa 3': '2016',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '39158.92',
#   'Rateio Faixa 3': '330.21',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e59'),
#   '': '1',
#   'Concurso': '2',
#   'Local': 'Belo Horizonte, MG',
#   'Data do Sorteio': '1996-03-18',
#   'Coluna 1': '9',
#   'Coluna 2': '37',
#   'Coluna 3': '39',
#   'Coluna 4': '41',
#   'Coluna 5': '43',
#   'Coluna 6': '49',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '65',
#   'Ganhadores Faixa 3': '4488',
#   'Rateio Faixa 1': '2307162.23',
#   'Rateio Faixa 2': '14424.02',
#   'Rateio Faixa 3': '208.91',
#   'Cidade': '',
#   'Unnamed: 16': 'PR',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e5a'),
#   '': '2',
#   'Concurso': '3',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-03-25',
#   'Coluna 1': '10',
#   'Coluna 2': '11',
#   'Coluna 3': '29',
#   'Coluna 4': '30',
#   'Coluna 5': '36',
#   'Coluna 6': '47',
#   'Ganhadores Faixa 1': '2',
#   'Ganhadores Faixa 2': '62',
#   'Ganhadores Faixa 3': '4261',
#   'Rateio Faixa 1': '391192.51',
#   'Rateio Faixa 2': '10515.93',
#   'Rateio Faixa 3': '153.01',
#   'Cidade': '',
#   'Unnamed: 16': 'RN',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e5b'),
#   '': '3',
#   'Concurso': '4',
#   'Local': 'Santo André, SP',
#   'Data do Sorteio': '1996-04-01',
#   'Coluna 1': '1',
#   'Coluna 2': '5',
#   'Coluna 3': '6',
#   'Coluna 4': '27',
#   'Coluna 5': '42',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '39',
#   'Ganhadores Faixa 3': '3311',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '15322.24',
#   'Rateio Faixa 3': '180.48',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e5c'),
#   '': '4',
#   'Concurso': '5',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-04-08',
#   'Coluna 1': '1',
#   'Coluna 2': '2',
#   'Coluna 3': '6',
#   'Coluna 4': '16',
#   'Coluna 5': '19',
#   'Coluna 6': '46',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '98',
#   'Ganhadores Faixa 3': '5399',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '5318.1',
#   'Rateio Faixa 3': '96.53',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e5d'),
#   '': '5',
#   'Concurso': '6',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-04-15',
#   'Coluna 1': '7',
#   'Coluna 2': '13',
#   'Coluna 3': '19',
#   'Coluna 4': '22',
#   'Coluna 5': '40',
#   'Coluna 6': '47',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '109',
#   'Ganhadores Faixa 3': '7147',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '7214.66',
#   'Rateio Faixa 3': '110.03',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e5e'),
#   '': '6',
#   'Concurso': '7',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-04-22',
#   'Coluna 1': '3',
#   'Coluna 2': '5',
#   'Coluna 3': '20',
#   'Coluna 4': '21',
#   'Coluna 5': '38',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '100',
#   'Ganhadores Faixa 3': '5736',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '8746.05',
#   'Rateio Faixa 3': '152.48',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e5f'),
#   '': '7',
#   'Concurso': '8',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-04-29',
#   'Coluna 1': '4',
#   'Coluna 2': '17',
#   'Coluna 3': '37',
#   'Coluna 4': '38',
#   'Coluna 5': '47',
#   'Coluna 6': '53',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '60',
#   'Ganhadores Faixa 3': '5262',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '16084.11',
#   'Rateio Faixa 3': '183.4',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e60'),
#   '': '8',
#   'Concurso': '9',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-05-06',
#   'Coluna 1': '8',
#   'Coluna 2': '43',
#   'Coluna 3': '54',
#   'Coluna 4': '55',
#   'Coluna 5': '56',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '17',
#   'Ganhadores Faixa 3': '2175',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '60043.79',
#   'Rateio Faixa 3': '469.31',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e61'),
#   '': '9',
#   'Concurso': '10',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-05-13',
#   'Coluna 1': '4',
#   'Coluna 2': '18',
#   'Coluna 3': '21',
#   'Coluna 4': '25',
#   'Coluna 5': '38',
#   'Coluna 6': '57',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '251',
#   'Ganhadores Faixa 3': '12590',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '6638.45',
#   'Rateio Faixa 3': '132.35',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e62'),
#   '': '10',
#   'Concurso': '11',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-05-20',
#   'Coluna 1': '15',
#   'Coluna 2': '25',
#   'Coluna 3': '37',
#   'Coluna 4': '38',
#   'Coluna 5': '58',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '148',
#   'Ganhadores Faixa 3': '9442',
#   'Rateio Faixa 1': '15591365.07',
#   'Rateio Faixa 2': '12706.05',
#   'Rateio Faixa 3': '199.16',
#   'Cidade': '',
#   'Unnamed: 16': 'RJ',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e63'),
#   '': '11',
#   'Concurso': '12',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-05-27',
#   'Coluna 1': '4',
#   'Coluna 2': '16',
#   'Coluna 3': '19',
#   'Coluna 4': '20',
#   'Coluna 5': '27',
#   'Coluna 6': '43',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '108',
#   'Ganhadores Faixa 3': '6454',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '6791.17',
#   'Rateio Faixa 3': '113.64',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e64'),
#   '': '12',
#   'Concurso': '13',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-06-03',
#   'Coluna 1': '18',
#   'Coluna 2': '32',
#   'Coluna 3': '47',
#   'Coluna 4': '50',
#   'Coluna 5': '54',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '43',
#   'Ganhadores Faixa 3': '2934',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '20543.98',
#   'Rateio Faixa 3': '301.09',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e65'),
#   '': '13',
#   'Concurso': '14',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-06-10',
#   'Coluna 1': '2',
#   'Coluna 2': '16',
#   'Coluna 3': '23',
#   'Coluna 4': '27',
#   'Coluna 5': '47',
#   'Coluna 6': '53',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '85',
#   'Ganhadores Faixa 3': '5323',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '10458.19',
#   'Rateio Faixa 3': '167',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e66'),
#   '': '14',
#   'Concurso': '15',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-06-17',
#   'Coluna 1': '12',
#   'Coluna 2': '33',
#   'Coluna 3': '35',
#   'Coluna 4': '51',
#   'Coluna 5': '52',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '57',
#   'Ganhadores Faixa 3': '3931',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '17919.89',
#   'Rateio Faixa 3': '259.84',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e67'),
#   '': '15',
#   'Concurso': '16',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-06-24',
#   'Coluna 1': '20',
#   'Coluna 2': '32',
#   'Coluna 3': '34',
#   'Coluna 4': '49',
#   'Coluna 5': '58',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '31',
#   'Ganhadores Faixa 3': '3250',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '33307.13',
#   'Rateio Faixa 3': '317.7',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e68'),
#   '': '16',
#   'Concurso': '17',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-07-01',
#   'Coluna 1': '6',
#   'Coluna 2': '10',
#   'Coluna 3': '13',
#   'Coluna 4': '19',
#   'Coluna 5': '20',
#   'Coluna 6': '51',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '144',
#   'Ganhadores Faixa 3': '9376',
#   'Rateio Faixa 1': '6789869.08',
#   'Rateio Faixa 2': '7628.37',
#   'Rateio Faixa 3': '117.16',
#   'Cidade': '',
#   'Unnamed: 16': 'SP',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e69'),
#   '': '17',
#   'Concurso': '18',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-07-08',
#   'Coluna 1': '23',
#   'Coluna 2': '27',
#   'Coluna 3': '36',
#   'Coluna 4': '37',
#   'Coluna 5': '42',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '52',
#   'Ganhadores Faixa 3': '4484',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '13763.52',
#   'Rateio Faixa 3': '159.61',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e6a'),
#   '': '18',
#   'Concurso': '19',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-07-15',
#   'Coluna 1': '5',
#   'Coluna 2': '10',
#   'Coluna 3': '12',
#   'Coluna 4': '24',
#   'Coluna 5': '25',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '159',
#   'Ganhadores Faixa 3': '9250',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '5380.14',
#   'Rateio Faixa 3': '92.48',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e6b'),
#   '': '19',
#   'Concurso': '20',
#   'Local': 'BRASÍLIA, DF',
#   'Data do Sorteio': '1996-07-22',
#   'Coluna 1': '11',
#   'Coluna 2': '25',
#   'Coluna 3': '28',
#   'Coluna 4': '30',
#   'Coluna 5': '33',
#   'Coluna 6': '51',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '72',
#   'Ganhadores Faixa 3': '5728',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '15486.97',
#   'Rateio Faixa 3': '194.67',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e6c'),
#   '': '20',
#   'Concurso': '21',
#   'Local': 'Bauru, SP',
#   'Data do Sorteio': '1996-07-29',
#   'Coluna 1': '6',
#   'Coluna 2': '33',
#   'Coluna 3': '36',
#   'Coluna 4': '46',
#   'Coluna 5': '49',
#   'Coluna 6': '53',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '63',
#   'Ganhadores Faixa 3': '5030',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '17694.19',
#   'Rateio Faixa 3': '221.62',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e6d'),
#   '': '21',
#   'Concurso': '22',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-08-05',
#   'Coluna 1': '1',
#   'Coluna 2': '9',
#   'Coluna 3': '31',
#   'Coluna 4': '38',
#   'Coluna 5': '46',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '47',
#   'Ganhadores Faixa 3': '4865',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '27212.9',
#   'Rateio Faixa 3': '262.9',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e6e'),
#   '': '22',
#   'Concurso': '23',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-08-12',
#   'Coluna 1': '17',
#   'Coluna 2': '37',
#   'Coluna 3': '39',
#   'Coluna 4': '51',
#   'Coluna 5': '52',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '74',
#   'Ganhadores Faixa 3': '4897',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '20198.46',
#   'Rateio Faixa 3': '305.23',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e6f'),
#   '': '23',
#   'Concurso': '24',
#   'Local': '',
#   'Data do Sorteio': '1996-08-19',
#   'Coluna 1': '1',
#   'Coluna 2': '8',
#   'Coluna 3': '14',
#   'Coluna 4': '28',
#   'Coluna 5': '33',
#   'Coluna 6': '43',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '227',
#   'Ganhadores Faixa 3': '13486',
#   'Rateio Faixa 1': '18661679.61',
#   'Rateio Faixa 2': '7897.31',
#   'Rateio Faixa 3': '132.93',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e70'),
#   '': '24',
#   'Concurso': '25',
#   'Local': 'Barretos, SP',
#   'Data do Sorteio': '1996-08-25',
#   'Coluna 1': '24',
#   'Coluna 2': '43',
#   'Coluna 3': '50',
#   'Coluna 4': '54',
#   'Coluna 5': '55',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '28',
#   'Ganhadores Faixa 3': '2741',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '26338.5',
#   'Rateio Faixa 3': '269.06',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e71'),
#   '': '25',
#   'Concurso': '26',
#   'Local': 'Ribeirão Preto, SP',
#   'Data do Sorteio': '1996-09-01',
#   'Coluna 1': '10',
#   'Coluna 2': '22',
#   'Coluna 3': '50',
#   'Coluna 4': '53',
#   'Coluna 5': '57',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '16',
#   'Ganhadores Faixa 3': '1823',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '52473.74',
#   'Rateio Faixa 3': '460.55',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e72'),
#   '': '26',
#   'Concurso': '27',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-09-08',
#   'Coluna 1': '13',
#   'Coluna 2': '17',
#   'Coluna 3': '20',
#   'Coluna 4': '33',
#   'Coluna 5': '44',
#   'Coluna 6': '51',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '99',
#   'Ganhadores Faixa 3': '6466',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '9306.24',
#   'Rateio Faixa 3': '142.49',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e73'),
#   '': '27',
#   'Concurso': '28',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-09-15',
#   'Coluna 1': '3',
#   'Coluna 2': '6',
#   'Coluna 3': '22',
#   'Coluna 4': '24',
#   'Coluna 5': '54',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '50',
#   'Ganhadores Faixa 3': '4895',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '19749.22',
#   'Rateio Faixa 3': '201.73',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e74'),
#   '': '28',
#   'Concurso': '29',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-09-22',
#   'Coluna 1': '3',
#   'Coluna 2': '8',
#   'Coluna 3': '14',
#   'Coluna 4': '43',
#   'Coluna 5': '56',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '44',
#   'Ganhadores Faixa 3': '5248',
#   'Rateio Faixa 1': '5401793.6',
#   'Rateio Faixa 2': '23083.15',
#   'Rateio Faixa 3': '193.53',
#   'Cidade': '',
#   'Unnamed: 16': 'RS',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e75'),
#   '': '29',
#   'Concurso': '30',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-09-29',
#   'Coluna 1': '7',
#   'Coluna 2': '14',
#   'Coluna 3': '15',
#   'Coluna 4': '29',
#   'Coluna 5': '38',
#   'Coluna 6': '50',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '80',
#   'Ganhadores Faixa 3': '5885',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '11347.74',
#   'Rateio Faixa 3': '154.26',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e76'),
#   '': '30',
#   'Concurso': '31',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-10-06',
#   'Coluna 1': '17',
#   'Coluna 2': '19',
#   'Coluna 3': '28',
#   'Coluna 4': '45',
#   'Coluna 5': '48',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '103',
#   'Ganhadores Faixa 3': '5680',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '8793.04',
#   'Rateio Faixa 3': '159.45',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e77'),
#   '': '31',
#   'Concurso': '32',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-10-13',
#   'Coluna 1': '5',
#   'Coluna 2': '14',
#   'Coluna 3': '33',
#   'Coluna 4': '36',
#   'Coluna 5': '43',
#   'Coluna 6': '44',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '96',
#   'Ganhadores Faixa 3': '6876',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '11430.91',
#   'Rateio Faixa 3': '159.6',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e78'),
#   '': '32',
#   'Concurso': '33',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-10-20',
#   'Coluna 1': '5',
#   'Coluna 2': '17',
#   'Coluna 3': '33',
#   'Coluna 4': '39',
#   'Coluna 5': '42',
#   'Coluna 6': '49',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '128',
#   'Ganhadores Faixa 3': '8722',
#   'Rateio Faixa 1': '13997410.74',
#   'Rateio Faixa 2': '9545.76',
#   'Rateio Faixa 3': '140.09',
#   'Cidade': '',
#   'Unnamed: 16': 'MG',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e79'),
#   '': '33',
#   'Concurso': '34',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-10-27',
#   'Coluna 1': '13',
#   'Coluna 2': '15',
#   'Coluna 3': '17',
#   'Coluna 4': '40',
#   'Coluna 5': '53',
#   'Coluna 6': '57',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '51',
#   'Ganhadores Faixa 3': '2627',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '13604.06',
#   'Rateio Faixa 3': '264.11',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e7a'),
#   '': '34',
#   'Concurso': '35',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-11-03',
#   'Coluna 1': '4',
#   'Coluna 2': '16',
#   'Coluna 3': '21',
#   'Coluna 4': '23',
#   'Coluna 5': '54',
#   'Coluna 6': '57',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '39',
#   'Ganhadores Faixa 3': '3576',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '20051.18',
#   'Rateio Faixa 3': '218.68',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e7b'),
#   '': '35',
#   'Concurso': '36',
#   'Local': 'São Bento do Sul, SC',
#   'Data do Sorteio': '1996-11-10',
#   'Coluna 1': '3',
#   'Coluna 2': '13',
#   'Coluna 3': '17',
#   'Coluna 4': '25',
#   'Coluna 5': '29',
#   'Coluna 6': '51',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '143',
#   'Ganhadores Faixa 3': '8548',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '6238.12',
#   'Rateio Faixa 3': '104.36',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e7c'),
#   '': '36',
#   'Concurso': '37',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-11-17',
#   'Coluna 1': '6',
#   'Coluna 2': '7',
#   'Coluna 3': '22',
#   'Coluna 4': '38',
#   'Coluna 5': '52',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '47',
#   'Ganhadores Faixa 3': '3695',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '16848.61',
#   'Rateio Faixa 3': '214.32',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e7d'),
#   '': '37',
#   'Concurso': '38',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-11-24',
#   'Coluna 1': '10',
#   'Coluna 2': '42',
#   'Coluna 3': '43',
#   'Coluna 4': '45',
#   'Coluna 5': '54',
#   'Coluna 6': '55',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '24',
#   'Ganhadores Faixa 3': '1999',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '38863.1',
#   'Rateio Faixa 3': '466.59',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e7e'),
#   '': '38',
#   'Concurso': '39',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-12-01',
#   'Coluna 1': '12',
#   'Coluna 2': '16',
#   'Coluna 3': '37',
#   'Coluna 4': '45',
#   'Coluna 5': '52',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '73',
#   'Ganhadores Faixa 3': '4444',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '13459.05',
#   'Rateio Faixa 3': '221.09',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e7f'),
#   '': '39',
#   'Concurso': '40',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-12-08',
#   'Coluna 1': '3',
#   'Coluna 2': '5',
#   'Coluna 3': '8',
#   'Coluna 4': '12',
#   'Coluna 5': '46',
#   'Coluna 6': '47',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '189',
#   'Ganhadores Faixa 3': '12117',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '7789.93',
#   'Rateio Faixa 3': '121.51',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e80'),
#   '': '40',
#   'Concurso': '41',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-12-15',
#   'Coluna 1': '12',
#   'Coluna 2': '26',
#   'Coluna 3': '35',
#   'Coluna 4': '38',
#   'Coluna 5': '39',
#   'Coluna 6': '47',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '148',
#   'Ganhadores Faixa 3': '10182',
#   'Rateio Faixa 1': '17019238.5',
#   'Rateio Faixa 2': '10114.7',
#   'Rateio Faixa 3': '147.03',
#   'Cidade': '',
#   'Unnamed: 16': 'BA',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': 'GANHADOR DA CIDADE DE SALVADOR, ESTADO DA BAHIA'},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e81'),
#   '': '41',
#   'Concurso': '42',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-12-22',
#   'Coluna 1': '7',
#   'Coluna 2': '11',
#   'Coluna 3': '19',
#   'Coluna 4': '24',
#   'Coluna 5': '33',
#   'Coluna 6': '36',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '201',
#   'Ganhadores Faixa 3': '9580',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '3684.64',
#   'Rateio Faixa 3': '77.31',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e82'),
#   '': '42',
#   'Concurso': '43',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1996-12-29',
#   'Coluna 1': '2',
#   'Coluna 2': '6',
#   'Coluna 3': '17',
#   'Coluna 4': '25',
#   'Coluna 5': '26',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '75',
#   'Ganhadores Faixa 3': '5070',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '9738.03',
#   'Rateio Faixa 3': '144.06',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e83'),
#   '': '43',
#   'Concurso': '44',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-01-05',
#   'Coluna 1': '14',
#   'Coluna 2': '18',
#   'Coluna 3': '29',
#   'Coluna 4': '38',
#   'Coluna 5': '44',
#   'Coluna 6': '47',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '103',
#   'Ganhadores Faixa 3': '7742',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '7099.32',
#   'Rateio Faixa 3': '94.45',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e84'),
#   '': '44',
#   'Concurso': '45',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-01-12',
#   'Coluna 1': '7',
#   'Coluna 2': '30',
#   'Coluna 3': '37',
#   'Coluna 4': '44',
#   'Coluna 5': '53',
#   'Coluna 6': '55',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '33',
#   'Ganhadores Faixa 3': '3004',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '27201.47',
#   'Rateio Faixa 3': '298.82',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e85'),
#   '': '45',
#   'Concurso': '46',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-01-19',
#   'Coluna 1': '1',
#   'Coluna 2': '23',
#   'Coluna 3': '24',
#   'Coluna 4': '32',
#   'Coluna 5': '46',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '91',
#   'Ganhadores Faixa 3': '6263',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '9982.42',
#   'Rateio Faixa 3': '145.04',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e86'),
#   '': '46',
#   'Concurso': '47',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-01-26',
#   'Coluna 1': '3',
#   'Coluna 2': '17',
#   'Coluna 3': '25',
#   'Coluna 4': '35',
#   'Coluna 5': '48',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '210',
#   'Ganhadores Faixa 3': '10873',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '4458.44',
#   'Rateio Faixa 3': '85.94',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e87'),
#   '': '47',
#   'Concurso': '48',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-02-02',
#   'Coluna 1': '2',
#   'Coluna 2': '5',
#   'Coluna 3': '28',
#   'Coluna 4': '34',
#   'Coluna 5': '47',
#   'Coluna 6': '50',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '132',
#   'Ganhadores Faixa 3': '7454',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '7482.95',
#   'Rateio Faixa 3': '132.25',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e88'),
#   '': '48',
#   'Concurso': '49',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-02-09',
#   'Coluna 1': '7',
#   'Coluna 2': '13',
#   'Coluna 3': '33',
#   'Coluna 4': '35',
#   'Coluna 5': '43',
#   'Coluna 6': '55',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '155',
#   'Ganhadores Faixa 3': '9830',
#   'Rateio Faixa 1': '8405156.76',
#   'Rateio Faixa 2': '6916.34',
#   'Rateio Faixa 3': '108.85',
#   'Cidade': '',
#   'Unnamed: 16': 'RJ',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': 'Ganhador RJ (Barra Mansa)'},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e89'),
#   '': '49',
#   'Concurso': '50',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-02-16',
#   'Coluna 1': '6',
#   'Coluna 2': '16',
#   'Coluna 3': '21',
#   'Coluna 4': '44',
#   'Coluna 5': '57',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '31',
#   'Ganhadores Faixa 3': '2800',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '25241.25',
#   'Rateio Faixa 3': '278.91',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e8a'),
#   '': '50',
#   'Concurso': '51',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-02-23',
#   'Coluna 1': '17',
#   'Coluna 2': '23',
#   'Coluna 3': '24',
#   'Coluna 4': '25',
#   'Coluna 5': '42',
#   'Coluna 6': '47',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '143',
#   'Ganhadores Faixa 3': '9361',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '7231.47',
#   'Rateio Faixa 3': '110.25',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e8b'),
#   '': '51',
#   'Concurso': '52',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-03-02',
#   'Coluna 1': '15',
#   'Coluna 2': '30',
#   'Coluna 3': '38',
#   'Coluna 4': '46',
#   'Coluna 5': '58',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '77',
#   'Ganhadores Faixa 3': '6442',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '15544.23',
#   'Rateio Faixa 3': '185.43',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e8c'),
#   '': '52',
#   'Concurso': '53',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-03-09',
#   'Coluna 1': '3',
#   'Coluna 2': '13',
#   'Coluna 3': '16',
#   'Coluna 4': '38',
#   'Coluna 5': '42',
#   'Coluna 6': '46',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '210',
#   'Ganhadores Faixa 3': '10941',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '6337.79',
#   'Rateio Faixa 3': '121.41',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e8d'),
#   '': '53',
#   'Concurso': '54',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-03-16',
#   'Coluna 1': '5',
#   'Coluna 2': '9',
#   'Coluna 3': '18',
#   'Coluna 4': '21',
#   'Coluna 5': '36',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '2',
#   'Ganhadores Faixa 2': '207',
#   'Ganhadores Faixa 3': '13067',
#   'Rateio Faixa 1': '7469653.99',
#   'Rateio Faixa 2': '7033.61',
#   'Rateio Faixa 3': '111.2',
#   'Cidade': '',
#   'Unnamed: 16': 'BA',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': 'Ganhadores dos estados: BA e SP.'},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e8e'),
#   '': '54',
#   'Concurso': '55',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-03-23',
#   'Coluna 1': '2',
#   'Coluna 2': '14',
#   'Coluna 3': '23',
#   'Coluna 4': '29',
#   'Coluna 5': '38',
#   'Coluna 6': '52',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '66',
#   'Ganhadores Faixa 3': '3840',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '10817.63',
#   'Rateio Faixa 3': '185.56',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e8f'),
#   '': '55',
#   'Concurso': '56',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-03-30',
#   'Coluna 1': '2',
#   'Coluna 2': '7',
#   'Coluna 3': '20',
#   'Coluna 4': '35',
#   'Coluna 5': '51',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '48',
#   'Ganhadores Faixa 3': '2599',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '12142.2',
#   'Rateio Faixa 3': '223.81',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e90'),
#   '': '56',
#   'Concurso': '57',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-04-06',
#   'Coluna 1': '7',
#   'Coluna 2': '16',
#   'Coluna 3': '17',
#   'Coluna 4': '27',
#   'Coluna 5': '34',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '79',
#   'Ganhadores Faixa 3': '6173',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '10699.1',
#   'Rateio Faixa 3': '136.65',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e91'),
#   '': '57',
#   'Concurso': '58',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-04-13',
#   'Coluna 1': '12',
#   'Coluna 2': '27',
#   'Coluna 3': '30',
#   'Coluna 4': '37',
#   'Coluna 5': '44',
#   'Coluna 6': '49',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '65',
#   'Ganhadores Faixa 3': '5040',
#   'Rateio Faixa 1': '3631304.91',
#   'Rateio Faixa 2': '13601.07',
#   'Rateio Faixa 3': '175.06',
#   'Cidade': '',
#   'Unnamed: 16': 'SP',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': 'Ganhador do Estado: SP'},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e92'),
#   '': '58',
#   'Concurso': '59',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-04-20',
#   'Coluna 1': '2',
#   'Coluna 2': '8',
#   'Coluna 3': '13',
#   'Coluna 4': '28',
#   'Coluna 5': '34',
#   'Coluna 6': '54',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '90',
#   'Ganhadores Faixa 3': '5351',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '7312.34',
#   'Rateio Faixa 3': '122.75',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e93'),
#   '': '59',
#   'Concurso': '60',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-04-27',
#   'Coluna 1': '3',
#   'Coluna 2': '14',
#   'Coluna 3': '15',
#   'Coluna 4': '20',
#   'Coluna 5': '21',
#   'Coluna 6': '38',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '129',
#   'Ganhadores Faixa 3': '7914',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '7111.47',
#   'Rateio Faixa 3': '115.69',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e94'),
#   '': '60',
#   'Concurso': '61',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-05-04',
#   'Coluna 1': '8',
#   'Coluna 2': '18',
#   'Coluna 3': '29',
#   'Coluna 4': '42',
#   'Coluna 5': '44',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '52',
#   'Ganhadores Faixa 3': '3866',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '18902.94',
#   'Rateio Faixa 3': '253.76',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e95'),
#   '': '61',
#   'Concurso': '62',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-05-11',
#   'Coluna 1': '6',
#   'Coluna 2': '8',
#   'Coluna 3': '13',
#   'Coluna 4': '24',
#   'Coluna 5': '31',
#   'Coluna 6': '52',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '119',
#   'Ganhadores Faixa 3': '8613',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '9968.7',
#   'Rateio Faixa 3': '137.46',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e96'),
#   '': '62',
#   'Concurso': '63',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-05-18',
#   'Coluna 1': '9',
#   'Coluna 2': '25',
#   'Coluna 3': '26',
#   'Coluna 4': '40',
#   'Coluna 5': '41',
#   'Coluna 6': '49',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '82',
#   'Ganhadores Faixa 3': '6359',
#   'Rateio Faixa 1': '13680019.57',
#   'Rateio Faixa 2': '16246.91',
#   'Rateio Faixa 3': '209.1',
#   'Cidade': '',
#   'Unnamed: 16': 'MG',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e97'),
#   '': '63',
#   'Concurso': '64',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-05-25',
#   'Coluna 1': '8',
#   'Coluna 2': '12',
#   'Coluna 3': '23',
#   'Coluna 4': '50',
#   'Coluna 5': '54',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '29',
#   'Ganhadores Faixa 3': '2441',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '23309.96',
#   'Rateio Faixa 3': '276.38',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e98'),
#   '': '64',
#   'Concurso': '65',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-06-01',
#   'Coluna 1': '1',
#   'Coluna 2': '5',
#   'Coluna 3': '20',
#   'Coluna 4': '25',
#   'Coluna 5': '32',
#   'Coluna 6': '34',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '61',
#   'Ganhadores Faixa 3': '4932',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '11542.37',
#   'Rateio Faixa 3': '142.48',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e99'),
#   '': '65',
#   'Concurso': '66',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-06-08',
#   'Coluna 1': '12',
#   'Coluna 2': '13',
#   'Coluna 3': '15',
#   'Coluna 4': '26',
#   'Coluna 5': '33',
#   'Coluna 6': '48',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '102',
#   'Ganhadores Faixa 3': '7686',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '8054.25',
#   'Rateio Faixa 3': '106.68',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e9a'),
#   '': '66',
#   'Concurso': '67',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-06-15',
#   'Coluna 1': '12',
#   'Coluna 2': '14',
#   'Coluna 3': '17',
#   'Coluna 4': '27',
#   'Coluna 5': '47',
#   'Coluna 6': '52',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '83',
#   'Ganhadores Faixa 3': '5479',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '10617.25',
#   'Rateio Faixa 3': '160.52',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e9b'),
#   '': '67',
#   'Concurso': '68',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-06-22',
#   'Coluna 1': '1',
#   'Coluna 2': '3',
#   'Coluna 3': '12',
#   'Coluna 4': '13',
#   'Coluna 5': '53',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '49',
#   'Ganhadores Faixa 3': '4758',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '18496.73',
#   'Rateio Faixa 3': '190.11',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e9c'),
#   '': '68',
#   'Concurso': '69',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-06-29',
#   'Coluna 1': '25',
#   'Coluna 2': '34',
#   'Coluna 3': '45',
#   'Coluna 4': '53',
#   'Coluna 5': '56',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '55',
#   'Ganhadores Faixa 3': '3661',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '17271.48',
#   'Rateio Faixa 3': '258.96',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e9d'),
#   '': '69',
#   'Concurso': '70',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-07-06',
#   'Coluna 1': '17',
#   'Coluna 2': '23',
#   'Coluna 3': '27',
#   'Coluna 4': '40',
#   'Coluna 5': '43',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '95',
#   'Ganhadores Faixa 3': '6071',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '12899.52',
#   'Rateio Faixa 3': '201.46',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e9e'),
#   '': '70',
#   'Concurso': '71',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-07-13',
#   'Coluna 1': '16',
#   'Coluna 2': '27',
#   'Coluna 3': '33',
#   'Coluna 4': '43',
#   'Coluna 5': '45',
#   'Coluna 6': '53',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '115',
#   'Ganhadores Faixa 3': '7430',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '12451.74',
#   'Rateio Faixa 3': '192.35',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba6e9f'),
#   '': '71',
#   'Concurso': '72',
#   'Local': 'Brasília, DF',
#   'Data do Sorteio': '1997-07-20',
#   'Coluna 1': '1',
#   'Coluna 2': '19',
#   'Coluna 3': '34',
#   'Coluna 4': '43',
#   'Coluna 5': '44',
#   'Coluna 6': '48',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '85',
#   'Ganhadores Faixa 3': '7982',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '19676.33',
#   'Rateio Faixa 3': '209.13',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '0',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
# ...
#   'Cidade': '',
#   'Unnamed: 16': 'SP',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '1300000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': 'Ganhador de seis acertos: São Paulo/SP.'},
#  {'_id': ObjectId('602d3e5c6980848c48ba7229'),
#   '': '977',
#   'Concurso': '978',
#   'Local': 'GOIÁS, GO',
#   'Data do Sorteio': '2008-06-14',
#   'Coluna 1': '12',
#   'Coluna 2': '16',
#   'Coluna 3': '18',
#   'Coluna 4': '27',
#   'Coluna 5': '42',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '69',
#   'Ganhadores Faixa 3': '4616',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '13220.26',
#   'Rateio Faixa 3': '197.61',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '3500000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba722a'),
#   '': '978',
#   'Concurso': '979',
#   'Local': 'IGUAPE, SP',
#   'Data do Sorteio': '2008-06-18',
#   'Coluna 1': '3',
#   'Coluna 2': '15',
#   'Coluna 3': '28',
#   'Coluna 4': '31',
#   'Coluna 5': '39',
#   'Coluna 6': '51',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '42',
#   'Ganhadores Faixa 3': '3714',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '23261.38',
#   'Rateio Faixa 3': '263.05',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '13000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba722b'),
#   '': '979',
#   'Concurso': '980',
#   'Local': 'JACUPIRANGA, SP',
#   'Data do Sorteio': '2008-06-21',
#   'Coluna 1': '15',
#   'Coluna 2': '17',
#   'Coluna 3': '29',
#   'Coluna 4': '35',
#   'Coluna 5': '36',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '88',
#   'Ganhadores Faixa 3': '6837',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '16054.57',
#   'Rateio Faixa 3': '206.64',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '16000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba722c'),
#   '': '980',
#   'Concurso': '981',
#   'Local': 'BARREIRAS, BA',
#   'Data do Sorteio': '2008-06-25',
#   'Coluna 1': '1',
#   'Coluna 2': '8',
#   'Coluna 3': '34',
#   'Coluna 4': '41',
#   'Coluna 5': '53',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '74',
#   'Ganhadores Faixa 3': '4974',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '20200.29',
#   'Rateio Faixa 3': '300.53',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '19000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba722d'),
#   '': '981',
#   'Concurso': '982',
#   'Local': 'BARREIRAS, BA',
#   'Data do Sorteio': '2008-06-28',
#   'Coluna 1': '8',
#   'Coluna 2': '12',
#   'Coluna 3': '24',
#   'Coluna 4': '40',
#   'Coluna 5': '43',
#   'Coluna 6': '49',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '125',
#   'Ganhadores Faixa 3': '8510',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '14102.62',
#   'Rateio Faixa 3': '207.15',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '23000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba722e'),
#   '': '982',
#   'Concurso': '983',
#   'Local': 'CRAVINHOS, SP',
#   'Data do Sorteio': '2008-07-02',
#   'Coluna 1': '16',
#   'Coluna 2': '22',
#   'Coluna 3': '32',
#   'Coluna 4': '38',
#   'Coluna 5': '40',
#   'Coluna 6': '45',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '244',
#   'Ganhadores Faixa 3': '9930',
#   'Rateio Faixa 1': '24038180.79',
#   'Rateio Faixa 2': '10258.56',
#   'Rateio Faixa 3': '252.07',
#   'Cidade': '',
#   'Unnamed: 16': 'SC',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '1500000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': 'Ganhador de seis acertos: Ibirama/SC.'},
#  {'_id': ObjectId('602d3e5c6980848c48ba722f'),
#   '': '983',
#   'Concurso': '984',
#   'Local': 'MORRO AGUDO, SP',
#   'Data do Sorteio': '2008-07-05',
#   'Coluna 1': '4',
#   'Coluna 2': '10',
#   'Coluna 3': '20',
#   'Coluna 4': '43',
#   'Coluna 5': '46',
#   'Coluna 6': '47',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '38',
#   'Ganhadores Faixa 3': '2643',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '26313.69',
#   'Rateio Faixa 3': '378.33',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '15000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7230'),
#   '': '984',
#   'Concurso': '985',
#   'Local': 'IPAMERI, GO',
#   'Data do Sorteio': '2008-07-09',
#   'Coluna 1': '4',
#   'Coluna 2': '16',
#   'Coluna 3': '18',
#   'Coluna 4': '46',
#   'Coluna 5': '56',
#   'Coluna 6': '59',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '55',
#   'Ganhadores Faixa 3': '4846',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '26215.6',
#   'Rateio Faixa 3': '297.54',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '17000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7231'),
#   '': '985',
#   'Concurso': '986',
#   'Local': 'IPAMERI, GO',
#   'Data do Sorteio': '2008-07-12',
#   'Coluna 1': '6',
#   'Coluna 2': '15',
#   'Coluna 3': '19',
#   'Coluna 4': '24',
#   'Coluna 5': '31',
#   'Coluna 6': '32',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '120',
#   'Ganhadores Faixa 3': '7953',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '15043.78',
#   'Rateio Faixa 3': '226.99',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '21000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7232'),
#   '': '986',
#   'Concurso': '987',
#   'Local': 'RIO CLARO, SP',
#   'Data do Sorteio': '2008-07-16',
#   'Coluna 1': '13',
#   'Coluna 2': '27',
#   'Coluna 3': '31',
#   'Coluna 4': '34',
#   'Coluna 5': '47',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '193',
#   'Ganhadores Faixa 3': '10923',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '10707.6',
#   'Rateio Faixa 3': '189.19',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '25000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7233'),
#   '': '987',
#   'Concurso': '988',
#   'Local': 'RIO CLARO, SP',
#   'Data do Sorteio': '2008-07-19',
#   'Coluna 1': '8',
#   'Coluna 2': '17',
#   'Coluna 3': '46',
#   'Coluna 4': '48',
#   'Coluna 5': '56',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '73',
#   'Ganhadores Faixa 3': '6874',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '31767.36',
#   'Rateio Faixa 3': '337.36',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '30000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7234'),
#   '': '988',
#   'Concurso': '989',
#   'Local': 'TOLEDO, PR',
#   'Data do Sorteio': '2008-07-23',
#   'Coluna 1': '2',
#   'Coluna 2': '21',
#   'Coluna 3': '27',
#   'Coluna 4': '29',
#   'Coluna 5': '32',
#   'Coluna 6': '38',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '130',
#   'Ganhadores Faixa 3': '10296',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '23437.38',
#   'Rateio Faixa 3': '295.93',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '52000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7235'),
#   '': '989',
#   'Concurso': '990',
#   'Local': 'JEQUERI, MG',
#   'Data do Sorteio': '2008-07-26',
#   'Coluna 1': '2',
#   'Coluna 2': '10',
#   'Coluna 3': '15',
#   'Coluna 4': '18',
#   'Coluna 5': '29',
#   'Coluna 6': '39',
#   'Ganhadores Faixa 1': '2',
#   'Ganhadores Faixa 2': '290',
#   'Ganhadores Faixa 3': '20863',
#   'Rateio Faixa 1': '26586140.51',
#   'Rateio Faixa 2': '18062.91',
#   'Rateio Faixa 3': '251.08',
#   'Cidade': '',
#   'Unnamed: 16': 'MG',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '2000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': 'Ganhadores da Sena: Belo Horizonte/MG e Ji-Paraná/RO.'},
#  {'_id': ObjectId('602d3e5c6980848c48ba7236'),
#   '': '990',
#   'Concurso': '991',
#   'Local': 'BARRA DO GARÇAS, MT',
#   'Data do Sorteio': '2008-07-30',
#   'Coluna 1': '8',
#   'Coluna 2': '9',
#   'Coluna 3': '15',
#   'Coluna 4': '38',
#   'Coluna 5': '41',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '36',
#   'Ganhadores Faixa 3': '3028',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '26823.95',
#   'Rateio Faixa 3': '318.91',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '4000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7237'),
#   '': '991',
#   'Concurso': '992',
#   'Local': 'ARAGARÇAS, GO',
#   'Data do Sorteio': '2008-08-02',
#   'Coluna 1': '1',
#   'Coluna 2': '4',
#   'Coluna 3': '6',
#   'Coluna 4': '8',
#   'Coluna 5': '25',
#   'Coluna 6': '28',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '330',
#   'Ganhadores Faixa 3': '13216',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '3731.21',
#   'Rateio Faixa 3': '93.17',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '6000000',
#   'Valor Acumulado Próximo Concurso': '0',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7238'),
#   '': '992',
#   'Concurso': '993',
#   'Local': 'TREMEMBÉ, SP',
#   'Data do Sorteio': '2008-08-06',
#   'Coluna 1': '5',
#   'Coluna 2': '24',
#   'Coluna 3': '25',
#   'Coluna 4': '26',
#   'Coluna 5': '42',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '68',
#   'Ganhadores Faixa 3': '5121',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '18539.43',
#   'Rateio Faixa 3': '246.18',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '8500000',
#   'Valor Acumulado Próximo Concurso': '331758.21',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba7239'),
#   '': '993',
#   'Concurso': '994',
#   'Local': 'TREMEMBÉ, SP',
#   'Data do Sorteio': '2008-08-09',
#   'Coluna 1': '3',
#   'Coluna 2': '20',
#   'Coluna 3': '29',
#   'Coluna 4': '40',
#   'Coluna 5': '44',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '47',
#   'Ganhadores Faixa 3': '3838',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '31786.28',
#   'Rateio Faixa 3': '389.25',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '25000000',
#   'Valor Acumulado Próximo Concurso': '724904.25',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba723a'),
#   '': '994',
#   'Concurso': '995',
#   'Local': 'BAURU, SP',
#   'Data do Sorteio': '2008-08-13',
#   'Coluna 1': '4',
#   'Coluna 2': '16',
#   'Coluna 3': '31',
#   'Coluna 4': '36',
#   'Coluna 5': '54',
#   'Coluna 6': '55',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '76',
#   'Ganhadores Faixa 3': '6790',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '24991.48',
#   'Rateio Faixa 3': '279.73',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '30000000',
#   'Valor Acumulado Próximo Concurso': '1224733.92',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba723b'),
#   '': '995',
#   'Concurso': '996',
#   'Local': 'BAURU, SP',
#   'Data do Sorteio': '2008-08-16',
#   'Coluna 1': '7',
#   'Coluna 2': '15',
#   'Coluna 3': '20',
#   'Coluna 4': '21',
#   'Coluna 5': '23',
#   'Coluna 6': '29',
#   'Ganhadores Faixa 1': '2',
#   'Ganhadores Faixa 2': '165',
#   'Ganhadores Faixa 3': '11901',
#   'Rateio Faixa 1': '14458257.67',
#   'Rateio Faixa 2': '13209.87',
#   'Rateio Faixa 3': '183.15',
#   'Cidade': '',
#   'Unnamed: 16': 'SC',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '1500000',
#   'Valor Acumulado Próximo Concurso': '1798320.37',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': 'Ganhadores da Sena: Barretos/SP e Joinville/SC.'},
#  {'_id': ObjectId('602d3e5c6980848c48ba723c'),
#   '': '996',
#   'Concurso': '997',
#   'Local': 'PONTE NOVA, MG',
#   'Data do Sorteio': '2008-08-20',
#   'Coluna 1': '9',
#   'Coluna 2': '17',
#   'Coluna 3': '18',
#   'Coluna 4': '32',
#   'Coluna 5': '53',
#   'Coluna 6': '55',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '40',
#   'Ganhadores Faixa 3': '3203',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '22382.42',
#   'Rateio Faixa 3': '279.52',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '3600000',
#   'Valor Acumulado Próximo Concurso': '2033924.78',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba723d'),
#   '': '997',
#   'Concurso': '998',
#   'Local': 'PONTE NOVA, MG',
#   'Data do Sorteio': '2008-08-23',
#   'Coluna 1': '3',
#   'Coluna 2': '4',
#   'Coluna 3': '21',
#   'Coluna 4': '22',
#   'Coluna 5': '28',
#   'Coluna 6': '32',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '40',
#   'Ganhadores Faixa 3': '4526',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '27708.98',
#   'Rateio Faixa 3': '244.89',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '6000000',
#   'Valor Acumulado Próximo Concurso': '2325598.27',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba723e'),
#   '': '998',
#   'Concurso': '999',
#   'Local': 'PRESIDENTE VENCESLAU, SP',
#   'Data do Sorteio': '2008-08-27',
#   'Coluna 1': '18',
#   'Coluna 2': '24',
#   'Coluna 3': '36',
#   'Coluna 4': '44',
#   'Coluna 5': '55',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '103',
#   'Ganhadores Faixa 3': '6681',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '11227.56',
#   'Rateio Faixa 3': '173.09',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '17000000',
#   'Valor Acumulado Próximo Concurso': '2629924.18',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5c6980848c48ba723f'),
#   '': '999',
#   'Concurso': '1000',
#   'Local': 'DUQUE DE CAXIAS, RJ',
#   'Data do Sorteio': '2008-08-30',
#   'Coluna 1': '29',
#   'Coluna 2': '38',
#   'Coluna 3': '39',
#   'Coluna 4': '49',
#   'Coluna 5': '53',
#   'Coluna 6': '58',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '41',
#   'Ganhadores Faixa 3': '3771',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '42451.22',
#   'Rateio Faixa 3': '461.55',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '0',
#   'Estimativa para o próximo concurso': '21000000',
#   'Valor Acumulado Próximo Concurso': '3087950.58',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  ...]

# %% [markdown]
# ##### <span style="color:blue">4) Ao find podem ser acrescentados os métodos skip, limit e sort. Skip pula os N primeiros documentos que atendem ao filtro; Limit controla a paginação do resultado; sort permite ordenar crescente (1) e decrescente (-1), de acordo com a chave passada. Vejam os exemplos</span>.

# %%
# No shell, a sintaxe é .sort({'Data do Sorteio': -1})
data = list((tb.find({}).sort('Data do Sorteio', -1).limit(5))) # apenas 5 registros de retorno (limitando)
data
# Out:
# [{'_id': ObjectId('602d3e5d6980848c48ba77d3'),
#   '': '2427',
#   'Concurso': '2344',
#   'Local': 'SÃO PAULO, SP',
#   'Data do Sorteio': '2021-02-13',
#   'Coluna 1': '11',
#   'Coluna 2': '17',
#   'Coluna 3': '25',
#   'Coluna 4': '38',
#   'Coluna 5': '52',
#   'Coluna 6': '57',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '59',
#   'Ganhadores Faixa 3': '4548',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '42795.9',
#   'Rateio Faixa 3': '793.11',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '43793878.5',
#   'Estimativa para o próximo concurso': '29000000',
#   'Valor Acumulado Próximo Concurso': '7345762.6',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5d6980848c48ba77d2'),
#   '': '2426',
#   'Concurso': '2343',
#   'Local': 'SÃO PAULO, SP',
#   'Data do Sorteio': '2021-02-10',
#   'Coluna 1': '4',
#   'Coluna 2': '31',
#   'Coluna 3': '42',
#   'Coluna 4': '45',
#   'Coluna 5': '49',
#   'Coluna 6': '56',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '24',
#   'Ganhadores Faixa 3': '2507',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '83892.9',
#   'Rateio Faixa 3': '1147.31',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '34921728',
#   'Estimativa para o próximo concurso': '11000000',
#   'Valor Acumulado Próximo Concurso': '6681299.97',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5d6980848c48ba77d1'),
#   '': '2425',
#   'Concurso': '2342',
#   'Local': 'SÃO PAULO, SP',
#   'Data do Sorteio': '2021-02-06',
#   'Coluna 1': '17',
#   'Coluna 2': '20',
#   'Coluna 3': '24',
#   'Coluna 4': '27',
#   'Coluna 5': '40',
#   'Coluna 6': '60',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '35',
#   'Ganhadores Faixa 3': '2233',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '51441.93',
#   'Rateio Faixa 3': '1151.85',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '31228029',
#   'Estimativa para o próximo concurso': '7500000',
#   'Valor Acumulado Próximo Concurso': '6151450.04',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5d6980848c48ba77d0'),
#   '': '2424',
#   'Concurso': '2341',
#   'Local': 'SÃO PAULO, SP',
#   'Data do Sorteio': '2021-02-03',
#   'Coluna 1': '4',
#   'Coluna 2': '9',
#   'Coluna 3': '31',
#   'Coluna 4': '32',
#   'Coluna 5': '42',
#   'Coluna 6': '46',
#   'Ganhadores Faixa 1': '1',
#   'Ganhadores Faixa 2': '59',
#   'Ganhadores Faixa 3': '3548',
#   'Rateio Faixa 1': '25099868.34',
#   'Rateio Faixa 2': '47999.27',
#   'Rateio Faixa 3': '1140.26',
#   'Cidade': "MIRASSOL D'OESTE",
#   'Unnamed: 16': 'MT',
#   'Valor Arrecadado': '49118593.5',
#   'Estimativa para o próximo concurso': '2500000',
#   'Valor Acumulado Próximo Concurso': '5677642.74',
#   'Acumulado': 'NAO',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''},
#  {'_id': ObjectId('602d3e5d6980848c48ba77cf'),
#   '': '2423',
#   'Concurso': '2340',
#   'Local': 'SÃO PAULO, SP',
#   'Data do Sorteio': '2021-01-30',
#   'Coluna 1': '16',
#   'Coluna 2': '21',
#   'Coluna 3': '28',
#   'Coluna 4': '41',
#   'Coluna 5': '49',
#   'Coluna 6': '51',
#   'Ganhadores Faixa 1': '0',
#   'Ganhadores Faixa 2': '24',
#   'Ganhadores Faixa 3': '2408',
#   'Rateio Faixa 1': '0',
#   'Rateio Faixa 2': '93309.21',
#   'Rateio Faixa 3': '1328.56',
#   'Cidade': '',
#   'Unnamed: 16': '',
#   'Valor Arrecadado': '38841412.5',
#   'Estimativa para o próximo concurso': '25000000',
#   'Valor Acumulado Próximo Concurso': '4932390.87',
#   'Acumulado': 'SIM',
#   'Sorteio Especial': 'SIM',
#   'Observação': ''}]

# %% [markdown]
# ##### <span style="color:blue">5) É importante notar que no .csv original não havia o campo _id, o qual é gerado e associado automaticamente a cada documento, sendo do tipo ObjectId: https://docs.mongodb.com/manual/reference/method/ObjectId/. Este não é um valor sequencial, mas seu algoritmo gerador considera o timestamp, o ID da máquina, o ID do processo e um contador local</span>

# %% [markdown]
# ##### <span style="color:blue">6) Vamos agora ver várias possibilidades de filtragem (consulta). Estes operadores também são utilizados para buscar dados para atualização (update) e remoção (delete)</span>

# %%
# Busca direta por valor em chave
d1 = tb.find({'Concurso': '2340'})
d1 = list(d1)
d1

# Busca por dois ou mais critérios (E) - ao menos 1 ganhador da sena de 01.Jan.2015 até o último concurso em 13.02
d2 = tb.find({'Data do Sorteio': {'$gt': '2015-01-01'}, 'Ganhadores Faixa 1': {'$gt' : '0'}}) 
d2 = list(d2)
d2

# Se, neste resultado, quisermos mostrar apenas determinada chave, pode-se ao final colocar chave: 1 (ou 0), chave: true (ou false).
# Por exemplo, vamos mostrar apenas o local e não mostrar o _id, que sempre é mostrado por default
d2 = tb.find({'Data do Sorteio': {'$gt': '2015-01-01'}, 'Ganhadores Faixa 1': {'$gt' : '0'}}, {'Local': True, '_id': False}) 
d2 = list(d2)
d2

# procurar numa faixa com $in - número de ganhadores na faixa 2 entre 10 e 30

d2 = tb.find({'Ganhadores Faixa 2': {'$in' : ['10', '30']}}, {'Local': True, '_id': False, 'Ganhadores Faixa 2': True}) 
d2 = list(d2)
d2

# uso do ou, operador $or - retorna ganhadores que contenham no local SP ou RN (uso de Regex). Similar ao uso de LIKE em SQL
# A string .*<palavra> busca no campo Local textos que começam com qualquer coisa e possuem RN. 
# Para verificar se começa com RN, seria $regex: '^RN'

d2 = tb.find({'$or': [{'Local': {'$regex': '.*SP'}},{'Local': {'$regex': '.*RN'}}]})
d2 = list(d2)
d2

# inserir um único documento insert_one ou vários insert_many
import datetime
tb.insert_one(
{
"Concurso": 99998,
"Data Sorteio": datetime.datetime(2016,9,7), # ou "07-09-2016" como string
"1ª Dezena": 1,
"2ª Dezena": 2,
"3ª Dezena": 3,
"4ª Dezena": 4,
"5ª Dezena": 5,
"6ª Dezena": 6,
"Arrecadacao_Total":0,
"Ganhadores_Sena":0,
"Rateio_Sena":0,
"Ganhadores_Quina":1,
"Rateio_Quina":"88000",
"Ganhadores_Quadra":55,
"Rateio_Quadra":"76200",
"Acumulado":"NAO",
"Valor_Acumulado":0,
"Estimativa_Prêmio":0,
"Acumulado_Mega_da_Virada":0
})

# %% [markdown]
# Resultado da inserção: ![](mongocrud3.png)

# %% [markdown]
# ##### <span style="color:blue">7) Atualização de dados - update_one, update_many e set</span>

# %%
# Deseja-se mudar para o documento do Concurso 99999 o Valor_Acumulado para 100.000,45. Pode-se passar a chave _id, como
# '_id': ObjectId('602d769575c3e5977478ba2c') e/ou criar um índice para agilizar as buscas

tb.create_index('Concurso')
tb.update_one({'Concurso': 99999}, {'$set': {'Valor_Acumulado': 100000.45}})

# Para alterar o valor de uma chave em todos os documentos, bastaria fazer
tb.update_many({}, {'$set': {'Acumulado_Mega_da_Virada': 100}})

# Com o upsert ao fim do update, caso o documento não exista é criado
tb.update_one({'Concurso': 100000}, {'$set': {'Ganhador': 'Josenalde'}}, True) #no shell seria upsert = 1

# %% [markdown]
# ![](mongocrud4.png)

# %% [markdown]
# ![](mongocrud5.png)

# %% [markdown]
#  ##### <span style="color:blue">8) Além de <code>set</code>, o update possui as opções $unset para remover chaves, $inc para auto incremento em uma unidade, ou no tamanho informado (size). </span>

# %%
tb.update_one({'Concurso': 100000}, {'$inc': {'Concurso': 1}}) # Concurso é incrementado em 1

# %% [markdown]
# ##### <span style="color:blue">9)Ampliando conhecimentos: pesquise sobre as ações sobre chaves com valores vetorizados, pull, pop (remover primeiro ou último elemento) e push (adicionar elementos) para</span>

# %%
tb.insert_one({ "_id" : 1,
        "sem" : 1,
        "notas" : [
                70,
                87,
                90,
                90,
                65,
                81
        ]})

# %%
tb.update_one( {'notas': 70 }, { '$pop': { 'notas' : 1 } } ) # primeiro elemento do array notas

# %%
d2 = list(tb.find({'_id': 1}, {'notas': True}))
d2
# Out:
# [{'_id': 1, 'notas': [70, 87, 90, 90, 65]}]

# %%
# Adicionando
tb.update_one({'notas': 70}, {'$push': {'notas': 81}})

# %%
d2 = list(tb.find({'_id': 1}, {'notas': True}))
d2
# Out:
# [{'_id': 1, 'notas': [70, 87, 90, 90, 65, 81]}]

# %% [markdown]
# ##### <span style="color:blue">10) Enfim, comandos para apagar documentos seguem as mesmas regras de update, com os comandos <code>delete_one</code> e <code>delete_many</code>, ou seja, delete_one({filtro_busca}) - remove já está desatualizado</span>

# %%
tb.delete_one({'_id': 1})
d2 = list(tb.find({'_id': 1}, {'notas': True}))
d2
# Out:
# []

# %% [markdown]
# ##### <span style="color:blue">11) Para apagar uma coleção inteira, usa-se o método drop, algo como <code>tb.drop()</code> no exemplo em questão. Já a remoção de chaves é feito com <code>unset</code> dentro de um <code>update</code>. Exemplo, remover a chave 'sem' do documento de notas acima</span>

# %%
tb.update_one({'_id': 1}, {'$unset': {'sem': ''}})
d2 = list(tb.find({'_id': 1}))
d2
# Out:
# [{'_id': 1, 'notas': [70, 87, 90, 90, 65, 81]}]

# %% [markdown]
# ##### <span style="color:blue">12) Este é o básico de CRUD no mongoDB. Outros comandos referem-se a agregações e agrupamentos de dados</span>
