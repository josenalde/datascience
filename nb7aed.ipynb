# %%
import pandas as pd
psgufrn = pd.read_csv('http://dados.ufrn.br/dataset/f7b1f5e2-37a1-44d9-8e9f-c0b92e310605/resource/083f9e7a-06e3-4121-87ee-c4b65291272c/download/requisicaopassagem.csv', sep=';', usecols=range(1,14))
psgufrn.shape
#c1 = psgufrn[(psgufrn.ano >= 2020) & (psgufrn.valor > 10000)]
#c2 = psgufrn[(psgufrn.valor > 50000) & (psgufrn.status != 'ESTORNADA')]
#c2
psgufrn.describe() # retorna valor 1 milhão ?
# Out:
#                 ano  id_unidade_requisitante  id_unidade_custo         valor
# count  38839.000000             38839.000000      38839.000000  3.883900e+04
# mean    2012.760627              2481.668967       2565.506913  1.901178e+03
# std        3.623181              3606.022816       3525.015476  5.130365e+04
# min     2006.000000                 2.000000          2.000000  0.000000e+00
# 25%     2010.000000               160.000000        252.000000  8.502400e+02
# 50%     2013.000000               364.000000        447.000000  1.266230e+03
# 75%     2016.000000              4885.000000       4656.000000  1.768195e+03
# max     2021.000000             30782.000000      30493.000000  1.000000e+07

# %%
import numpy
import matplotlib.pyplot as plt
from numpy.random import randn, shuffle
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

N = 32
x = sorted(randn(N))
y = sorted(randn(N))

X, Y = meshgrid(x, y)
Z = X**2 - Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.jet, linewidth=0)
fig.colorbar(surf)

title = ax.set_title("Grafico f(x,y)")
title.set_y(1.01)

ax.xaxis.set_major_locator(MaxNLocator(5))
ax.yaxis.set_major_locator(MaxNLocator(6))
ax.zaxis.set_major_locator(MaxNLocator(5))

fig.tight_layout()
