# %%
import pandas as pd
psgufrn = pd.read_csv('http://dados.ufrn.br/dataset/f7b1f5e2-37a1-44d9-8e9f-c0b92e310605/resource/083f9e7a-06e3-4121-87ee-c4b65291272c/download/requisicaopassagem.csv', sep=';')

psgufrn.info()
#psgufrn.head() #tail
#psgufrn.shape
c1 = psgufrn[(psgufrn.ano >= 2020) & (psgufrn.valor > 10000)]
#c1
c2 = psgufrn[(psgufrn.valor > 50000) & (psgufrn.status != 'ESTORNADA')]
#c2
#psgufrn.describe() # retorna valor 1 milhão ?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38839 entries, 0 to 38838
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   numero                     38839 non-null  int64
#  1   ano                        38839 non-null  int64
#  2   proponente                 38839 non-null  object
#  3   proposto                   38837 non-null  object
#  4   tipo_proposto              38752 non-null  object
#  5   id_unidade_requisitante    38839 non-null  int64
#  6   nome_unidade_requisitante  38839 non-null  object
#  7   id_unidade_custo           38839 non-null  int64
#  8   nome_unidade_custo         38839 non-null  object
#  9   data_envio                 34718 non-null  object
#  10  data_autorizacao_chefe     25357 non-null  object
#  11  descricao                  38838 non-null  object
#  12  valor                      38839 non-null  float64
# ...

# %%
import numpy
import matplotlib
import matplotlib.pyplot as plt
from numpy.random import randn, shuffle
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from numpy import meshgrid

N = 32
x = sorted(randn(N))
y = sorted(randn(N))

X, Y = meshgrid(x, y)
Z = X**2 - Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.jet, linewidth=0)
fig.colorbar(surf)

title = ax.set_title("Grafico f(x,y)")
title.set_y(1.01)

ax.xaxis.set_major_locator(MaxNLocator(5))
ax.yaxis.set_major_locator(MaxNLocator(6))
ax.zaxis.set_major_locator(MaxNLocator(5))

fig.tight_layout()
