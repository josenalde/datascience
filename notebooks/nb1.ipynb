# %% [markdown]
# ## 1) Leitura de arquivo .csv no disco local. Para este arquivo, não consegue ler sem o informar explicitamente o separador <code>sep=';'<code>

# %% [markdown]
# Tutorial de python. $y=x_2$

# %%
import pandas as pd
acervobczm = pd.read_csv('../datasets/acervoaquisicao.csv', sep=';')
print(acervobczm.shape[0]) #quantos exemplares (linhas)
acervobczm.tail()
#print(type(acervobczm))
# Out:
# 47644
#                                                   titulo  edicao   ano  \
# 47639  MYSQL PROJETO MODELAGEM E DESENVOLVIMENTO DE B...       0     0
# 47640                           PASCAL ESTRUTURADO, 3 ED       0     0
# 47641                      WINDOWS XP PRO, GUIA DE BOLSO       2     0
# 47642                               PARASITOLOGIA HUMANA      11  2005
# 47643  VIGIAR E PUNIR- HISTÓRIA DA VIOLÊNCIA NAS PRISÕES      26  2002
#
#                    autor                                 gestora_nome  \
# 47639  RANGEL, ALEXANDRE  UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE
# 47640      FARRER, HARRY  UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE
# 47641    STANEK, WILLIAN  UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE
# 47642        NEVES, D. P  UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE
# 47643        M. FOCAULT.  UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE
#
#        quantidade                unidade_nome  ano_aquisicao        isbn  issn
# ...

# %% [markdown]
# #### Exibe $\color{red}{\text{dados}}$ com colunas que tenham no máximo 2 NaN; (dropna()) geral não exibe se tiver pelo menos um

# %% [markdown]
# Para aprender Markdown sob demanda, referências como esta já dão um bom início para os principais aspectos: <a> href="https://www.datacamp.com/community/tutorials/markdown-in-jupyter-notebook"></a>

# %%
from collections import Counter

# %%
acervobczm.dropna(thresh=3)
Counter(acervobczm["unidade_nome"])
# Out:
# Counter({'COORDENAÇÃO DO CURSO DE MEDICINA': 214,
#          'COORDENAÇÃO DO CURSO DE GEOGRAFIA A DISTÂNCIA - NATAL': 1,
#          'COORDENAÇÃO DO CURSO DE GESTÃO DE POLÍTICAS PÚBLICAS': 119,
#          'COORDENAÇÃO DO CURSO DE JORNALISMO': 2,
#          'CERES-COORDENAÇÃO DO CURSO DE LETRAS- LÍNGUA PORTUGUESA': 1,
#          'CB - COORDENAÇÃO DO CURSO DE CIÊNCIAS BIOLÓGICAS - BACHARELADO': 1,
#          'COORDENAÇÃO DO CURSO DE ENFERMAGEM': 36,
#          'COORDENAÇÃO DO CURSO DE FARMÁCIA': 68,
#          'COORDENAÇÃO DO CURSO DE ODONTOLOGIA': 69,
#          'COORDENAÇÃO DO CURSO DE MATEMÁTICA - LICENCIATURA': 37,
#          'COORDENAÇÃO DO CURSO DE METEOROLOGIA': 1,
#          'COORDENAÇÃO DO CURSO DE FILOSOFIA - BACHARELADO': 4,
#          'COORDENAÇÃO DO CURSO DE LETRAS- LÍNGUA INGLESA': 1,
#          'COORDENAÇÃO DO CURSO DE PSICOLOGIA': 68,
#          'PROGRAMA DE PÓS-GRADUAÇÃO EM CIÊNCIAS SOCIAIS': 34,
#          'COORDENAÇÃO DO CURSO DE BIBLIOTECONOMIA': 158,
# ...

# %% [markdown]
# Ler arquivo .csv 'na mão'

# %%
import csv

with open('../datasets/acervoaquisicao.csv', encoding='utf8') as f:
    reader = csv.DictReader(f, delimiter=';')
    print(type(reader))
    #for row in reader:
    #    print(row['titulo'])
        #edicao = row["edicao"]
    #    ano = row["ano"]
    #    autor = row["autor"]
        #gestora_nome = row["gestora_nome"]
        #quantidade = row["quantidade"]
        #unidade_nome = row["unidade_nome"]
    #    ano_aquisicao = row["ano_aquisicao"]
        #isbn = row["isbn"]
        #issn = row["issn"]
# Out:
# <class 'csv.DictReader'>

# %%
import numpy as np
data = {i : np.random.randn() for i in range(7)}
data
data?
# %pwd
# Out:
# 'C:\\Users\\josen\\OneDrive\\ensino\\tads\\tad0204cienciadados\\notebooks'
# Type:        dict
# String form: {0: -0.4701279511451709, 1: 1.0309244697713078, 2: -1.2036678062225374, 3: -0.14660293810504654, 4: 0.48949365274537826, 5: -1.2891770810256595, 6: 1.0789853480921656}
# Length:      7
# Docstring:
# dict() -> new empty dictionary
# dict(mapping) -> new dictionary initialized from a mapping object's
#     (key, value) pairs
# dict(iterable) -> new dictionary initialized as if via:
#     d = {}
#     for k, v in iterable:
#         d[k] = v
# dict(**kwargs) -> new dictionary initialized with the name=value pairs
#     in the keyword argument list.  For example:  dict(one=1, two=2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(np.random.randn(50).cumsum())

# %%
np
# Out:
# <module 'numpy' from 'C:\\Users\\josen\\anaconda3\\lib\\site-packages\\numpy\\__init__.py'>
